# %%
from premise import *
import brightway2 as bw
bw.projects.set_current("ei39")

# %%
scenarios = [
    #{"model": "image", "pathway":"SSP1-RCP19", "year": 2050, "filepath":"/Users/romain/Documents"},
    {"model": "image", "pathway":"SSP2-Base", "year": 2050,},
    #{"model": "remind", "pathway":"SSP1-PkBudg500", "year": 2050,},
]

# %%
ndb = NewDatabase(
        scenarios = scenarios,
        source_db= "ecoinvent 3.9.1 cutoff",
        source_version="3.9.1",
        #source_type=source,
        #source_file_path=f"/Users/romain/Documents/ecoinvent {ei}_cutoff_ecoSpold02/datasets" if source == "ecospold" else None, # <-- this is NEW
        #source_version=ei,
        key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
        #system_model="cutoff",
        #system_args=combinations[0]
)
# Out:
# premise v.(2, 0, 0)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
# [('refinery gas, burned in furnace', 'production', 1.0, 'megajoule'),
#  ('petroleum refinery operation', 'technosphere', 0.0199, 'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.0561, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 1.5e-05, 'kilogram'),
#  ('Mercury II', 'biosphere', 1.39e-09, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 4.97e-06, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   4.97e-06,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 5e-05, 'kilogram'),
#  ('Particulate Matter, < 2.5 um', 'biosphere', 5.46e-06, 'kilogram'),
#  ('Radon-222', 'biosphere', 0.00636, 'kilo Becquerel'),
#  ('Sulfur dioxide', 'biosphere', 5.77e-06, 'kilogram')] 1.0 0.0 in refinery gas, burned in furnace
#
# 0.0 1.0
# issue with refinery gas, burned in furnace
# [('heat and power co-generation, natural gas, 500kW electrical, lean burn',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('heat and power co-generation unit construction, 500kW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   1.6436417887532573e-08,
#   'unit'),
#  ('heat and power co-generation unit construction, 500kW electrical, '
#   'components for electricity only',
#   'technosphere',
#   1.6436417887532573e-08,
#   'unit'),
#  ('heat and power co-generation unit construction, 500kW electrical, '
#   'components for heat only',
#   'technosphere',
#   1.6436417887532573e-08,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.0002465462683129886,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.21072330625041735,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -0.0002465462683129886,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.4602197008509137, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.001314913431002607, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 4.1091044718831425e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 0.0006574567155013036, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   8.218208943766285e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.0005752746260636392, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.2327313415649428e-06,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 4.520014919071446e-06, 'kilogram')] 3.6 0.0 in heat and power co-generation, natural gas, 500kW electrical, lean burn
#
# 0.0 3.6
# issue with heat and power co-generation, natural gas, 500kW electrical, lean burn
# [('heat and power co-generation, natural gas, 160kW electrical, Jakobsberg',
#   'production',
#   1.0,
#   'megajoule'),
#  ('heat and power co-generation unit construction, 160kW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   2.402397823919752e-09,
#   'unit'),
#  ('heat and power co-generation unit construction, 160kW electrical, '
#   'components for electricity only',
#   'technosphere',
#   2.402397823919752e-09,
#   'unit'),
#  ('heat and power co-generation unit construction, 160kW electrical, '
#   'components for heat only',
#   'technosphere',
#   2.402397823919752e-09,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   1.4414386943518444e-05,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.012319988840614023,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -1.4414386943518444e-05,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.026906855627901058, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 2.3063019109629514e-05, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.2011989119598715e-06, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 1.10510299900308e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   9.609591295678963e-07,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 7.2071934717592345e-06, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   7.207193471759232e-08,
#   'kilogram'),
#  ('Platinum', 'biosphere', 3.3633569534876437e-12, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 2.642637606311725e-07, 'kilogram')] 1.0 0.0 in heat and power co-generation, natural gas, 160kW electrical, Jakobsberg
#
# 0.0 1.0
# issue with heat and power co-generation, natural gas, 160kW electrical, Jakobsberg
# [('natural gas, burned in polymer electrolyte membrane fuel cell 2kWe, future',
#   'production',
#   1.0,
#   'megajoule'),
#  ('fuel cell production, polymer electrolyte membrane, 2kW electrical, future',
#   'technosphere',
#   2.912300255640645e-07,
#   'unit'),
#  ('maintenance, polymer electrolyte membrane fuel cell 2kW electrical',
#   'technosphere',
#   4.077339773481621e-06,
#   'unit'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.009005700204919578,
#   'cubic meter'),
#  ('storage production, 650 l mini CHP plant',
#   'technosphere',
#   2.0502602229045535e-07,
#   'unit'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.019668449247564026, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 5.970779235867651e-07, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 1.404889231968859e-06, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.0536669239766442e-07,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 4.5658900038987917e-07, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   7.024446159844295e-11,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 1.9317226939571812e-07, 'kilogram')] 1.0 0.0 in natural gas, burned in polymer electrolyte membrane fuel cell 2kWe, future
#
# 0.0 1.0
# issue with natural gas, burned in polymer electrolyte membrane fuel cell 2kWe, future
# [('ethanol production from sweet sorghum', 'production', 1.0, 'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   4.998410990357581e-09,
#   'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   1.0888640774129121e-08,
#   'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   2.360955277529007e-08,
#   'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   1.1824785105470356e-07,
#   'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   1.11812031115527e-09,
#   'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   1.0667991968845098e-08,
#   'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   3.532431302584965e-09,
#   'kilogram'),
#  ('market for ammonia, anhydrous, liquid',
#   'technosphere',
#   5.495553263872572e-09,
#   'kilogram'),
#  ('market for ammonium sulfate',
#   'technosphere',
#   0.0031093933233227915,
#   'kilogram'),
#  ('market for ammonium sulfate',
#   'technosphere',
#   0.000954166461014918,
#   'kilogram'),
#  ('market for chemical, organic',
#   'technosphere',
#   0.00012498682450463698,
#   'kilogram'),
#  ('market for chlorine, liquid',
#   'technosphere',
#   1.190529990429119e-06,
#   'kilogram'),
#  ('market for chlorine, liquid',
#   'technosphere',
#   5.951534626940428e-06,
#   'kilogram'),
#  ('market for ethanol fermentation plant',
#   'technosphere',
#   4.0419163234357824e-10,
#   'unit'),
#  ('market for heat and power co-generation unit, 6400kW thermal, building',
#   'technosphere',
#   5.247706827914563e-09,
#   'unit'),
#  ('market for heat and power co-generation unit, 6400kW thermal, common '
#   'components for heat+electricity',
#   'technosphere',
#   2.1012193292292176e-08,
#   'unit'),
#  ('market for heat and power co-generation unit, 6400kW thermal, components '
#   'for electricity only',
#   'technosphere',
#   2.1012193292292176e-08,
#   'unit'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   6.87219298765762e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   5.761428085223521e-06,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   1.5036675324270083e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   0.0036942970038184733,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   3.328176950481413e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   1.1117943416393214e-06,
#   'kilogram'),
#  ('market group for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   0.0004865026739956732,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   5.480734328599766e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   0.00044258679750091987,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   0.00011917474532448652,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   6.1354576631207e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   4.27560416568702e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   6.657040193766307e-06,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   2.4332511347421075e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   1.571953666373374e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   5.394947728164633e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   0.00015019518004183053,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   1.5764145695960007e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   1.2538569519599015e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   2.2990808916615597e-07,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   4.041921466101718e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   1.722594936737467e-06,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   1.612788088180497e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   4.134914140973402e-06,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   0.0005819213939276625,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   4.783803986664747e-05,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   6.3996803924609095e-06,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   2.3677101720096658e-06,
#   'kilogram'),
#  ('market for inorganic nitrogen fertiliser, as N',
#   'technosphere',
#   8.969846941497488e-05,
#   'kilogram'),
#  ('market for lubricating oil',
#   'technosphere',
#   4.470390254029415e-05,
#   'kilogram'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.00021221507757635655,
#   'kilogram'),
#  ('market for municipal solid waste',
#   'technosphere',
#   -2.3444769227172584e-08,
#   'kilogram'),
#  ('market for municipal solid waste',
#   'technosphere',
#   -6.580443711885305e-05,
#   'kilogram'),
#  ('market for municipal solid waste',
#   'technosphere',
#   -3.350397368985164e-08,
#   'kilogram'),
#  ('market group for municipal solid waste',
#   'technosphere',
#   -5.466216268903585e-06,
#   'kilogram'),
#  ('market for municipal solid waste',
#   'technosphere',
#   -9.30440430218218e-08,
#   'kilogram'),
#  ('market for sodium chloride, powder',
#   'technosphere',
#   8.927650141778945e-05,
#   'kilogram'),
#  ('market for sulfuric acid', 'technosphere', 0.003525788903157749, 'kilogram'),
#  ('market for sulfuric acid', 'technosphere', 0.026951256329710026, 'kilogram'),
#  ('market for sweet sorghum stem',
#   'technosphere',
#   13.874013398674277,
#   'kilogram'),
#  ('market group for tap water', 'technosphere', 11.873658146853444, 'kilogram'),
#  ('vinasse, from fermentation of sweet sorghum, Recycled Content cut-off',
#   'technosphere',
#   -10.660930635675287,
#   'kilogram'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -5.1330979542250106e-05,
#   'kilogram'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -1.9604341127125063e-05,
#   'kilogram'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -4.853255043203002e-07,
#   'kilogram'),
#  ('market for wastewater, average',
#   'technosphere',
#   -1.372412462389849e-05,
#   'cubic meter'),
#  ('market for wastewater, average',
#   'technosphere',
#   -4.8863112641884024e-08,
#   'cubic meter'),
#  ('market for wastewater, average',
#   'technosphere',
#   -3.2817191539091545e-06,
#   'cubic meter'),
#  ('market for wastewater, average',
#   'technosphere',
#   -8.247445959294425e-08,
#   'cubic meter'),
#  ('market for water, decarbonised',
#   'technosphere',
#   5.673111130564297e-07,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.0008934464872289666,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   3.269575641914593e-05,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.0010852908249775178,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.006807733356677156,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.0005922508769637414,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   4.453529269162794e-05,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.005778853711201946,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.00018011442681192545,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.00034863597435704554,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.00046590767738933847,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.0009071496542110061,
#   'kilogram'),
#  ('market for wood ash mixture, pure',
#   'technosphere',
#   -0.007733647891010013,
#   'kilogram'),
#  ('market for wood ash mixture, pure',
#   'technosphere',
#   -7.624409235987216e-05,
#   'kilogram'),
#  ('market for wood ash mixture, pure',
#   'technosphere',
#   -0.0037090076408794336,
#   'kilogram'),
#  ('Acetaldehyde', 'biosphere', 1.3282564207488806e-06, 'kilogram'),
#  ('Ammonia', 'biosphere', 3.788854319043962e-05, 'kilogram'),
#  ('Arsenic ion', 'biosphere', 2.1775264029219278e-08, 'kilogram'),
#  ('Benzene', 'biosphere', 1.7769836361022063e-05, 'kilogram'),
#  ('Benzene, ethyl-', 'biosphere', 5.858024677322243e-07, 'kilogram'),
#  ('Benzene, hexachloro-', 'biosphere', 1.4059925178216522e-13, 'kilogram'),
#  ('Benzo(a)pyrene', 'biosphere', 9.763420708915099e-09, 'kilogram'),
#  ('Bromine', 'biosphere', 1.3064880937263625e-06, 'kilogram'),
#  ('Cadmium II', 'biosphere', 1.5241991119783606e-08, 'kilogram'),
#  ('Calcium', 'biosphere', 0.00012738286661858833, 'kilogram'),
#  ('Carbon dioxide, non-fossil', 'biosphere', 4.283185416438728, 'kilogram'),
#  ('Carbon monoxide, non-fossil',
#   'biosphere',
#   0.00013668678000373902,
#   'kilogram'),
#  ('Chlorine', 'biosphere', 3.9194087851254855e-06, 'kilogram'),
#  ('Chromium III', 'biosphere', 8.622838067410057e-08, 'kilogram'),
#  ('Chromium VI', 'biosphere', 8.709966871553764e-10, 'kilogram'),
#  ('Copper ion', 'biosphere', 4.790419346294259e-07, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 5.008241356653443e-05, 'kilogram'),
#  ('Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   'biosphere',
#   6.053232045841589e-13,
#   'kilogram'),
#  ('Fluorine', 'biosphere', 1.0887354534341673e-06, 'kilogram'),
#  ('Formaldehyde', 'biosphere', 2.5385282315554338e-06, 'kilogram'),
#  ('Hydrocarbons, aliphatic, alkanes, unspecified',
#   'biosphere',
#   1.7769836361022063e-05,
#   'kilogram'),
#  ('Hydrocarbons, aliphatic, unsaturated',
#   'biosphere',
#   6.053232045841589e-05,
#   'kilogram'),
#  ('Lead II', 'biosphere', 5.421964436201912e-07, 'kilogram'),
#  ('Magnesium', 'biosphere', 7.860738511420873e-06, 'kilogram'),
#  ('Manganese II', 'biosphere', 3.7235077159362024e-06, 'kilogram'),
#  ('Mercury II', 'biosphere', 6.532440468631804e-09, 'kilogram'),
#  ('Methane, non-fossil', 'biosphere', 8.474663604312213e-06, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.19112567231638e-05,
#   'kilogram'),
#  ('Nickel II', 'biosphere', 1.3064880937263625e-07, 'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.001916139990490906, 'kilogram'),
#  ('PAH, polycyclic aromatic hydrocarbons',
#   'biosphere',
#   2.1479747543827525e-07,
#   'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   0.0008767544027158262,
#   'kilogram'),
#  ('Phenol, pentachloro-', 'biosphere', 1.5816375274488723e-10, 'kilogram'),
#  ('Phosphorus', 'biosphere', 6.532440468631804e-06, 'kilogram'),
#  ('Potassium I', 'biosphere', 0.000509523142066313, 'kilogram'),
#  ('Sodium', 'biosphere', 2.8307149537315156e-05, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 5.421964436201911e-05, 'kilogram'),
#  ('Toluene', 'biosphere', 5.858024677322243e-06, 'kilogram'),
#  ('Water', 'biosphere', 1.096803473097685e-05, 'cubic meter'),
#  ('Zinc II', 'biosphere', 6.532440468631804e-06, 'kilogram'),
#  ('m-Xylene', 'biosphere', 2.3431821229020994e-06, 'kilogram'),
#  ('Water', 'biosphere', 0.011879458478060581, 'cubic meter'),
#  ('Carbon dioxide, in air', 'biosphere', 0.8613403738298959, 'kilogram')] 26.5 0.0 in ethanol production from sweet sorghum
#
# 0.0 26.5
# issue with ethanol production from sweet sorghum
# [('heat and power co-generation, natural gas, 160kW electrical, lambda=1',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('market for heat and power co-generation unit, 160kW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   4.354530098868791e-08,
#   'unit'),
#  ('market for heat and power co-generation unit, 160kW electrical, components '
#   'for electricity only',
#   'technosphere',
#   4.354530098868791e-08,
#   'unit'),
#  ('market for heat and power co-generation unit, 160kW electrical, components '
#   'for heat only',
#   'technosphere',
#   4.354530098868791e-08,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.00026127180593212744,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.006879885107506555,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0032768581768939714,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.06421731788329714,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.009125139784267239,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.13981003488745997,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -0.00026127180593212744,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.48770737107330503, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.00041803488949140416, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 2.1772650494343955e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 0.00020030838454796458, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.7418120395475163e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.00013063590296606372, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.3063590296606372e-06,
#   'kilogram'),
#  ('Platinum', 'biosphere', 6.096342138416288e-11, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 4.789983108755665e-06, 'kilogram')] 3.6 0.0 in heat and power co-generation, natural gas, 160kW electrical, lambda=1
#
# 0.0 3.6
# issue with heat and power co-generation, natural gas, 160kW electrical, lambda=1
# [('heat and power co-generation, natural gas, 1MW electrical, lean burn',
#   'production',
#   1.0,
#   'megajoule'),
#  ('heat and power co-generation unit construction, 1MW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('heat and power co-generation unit construction, 1MW electrical, components '
#   'for electricity only',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('heat and power co-generation unit construction, 1MW electrical, components '
#   'for heat only',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   1.1156678819652644e-05,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.009535622922780018,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -1.1156678819652644e-05,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.02082580046335158, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 5.9502287038147395e-05, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.8594464699420989e-06, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 2.975114351907378e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   3.718892939884214e-06,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 2.6032250579189516e-05, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   5.5783394098263125e-08,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 2.0453911169363203e-07, 'kilogram')] 1.0 0.0 in heat and power co-generation, natural gas, 1MW electrical, lean burn
#
# 0.0 1.0
# issue with heat and power co-generation, natural gas, 1MW electrical, lean burn
# [('heat and power co-generation, natural gas, 1MW electrical, lean burn',
#   'production',
#   1.0,
#   'megajoule'),
#  ('heat and power co-generation unit construction, 1MW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('heat and power co-generation unit construction, 1MW electrical, components '
#   'for electricity only',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('heat and power co-generation unit construction, 1MW electrical, components '
#   'for heat only',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   1.1156678819652644e-05,
#   'kilogram'),
#  ('market group for natural gas, high pressure',
#   'technosphere',
#   0.009535622922780018,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -1.1156678819652644e-05,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.02082580046335158, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 3.979215445676111e-05, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.8594464699420989e-06, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 4.983316539444844e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 2.975114351907378e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   3.718892939884214e-06,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 3.904837586878419e-05, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   5.5783394098263125e-08,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 2.0453911169363203e-07, 'kilogram')] 1.0 0.0 in heat and power co-generation, natural gas, 1MW electrical, lean burn
#
# 0.0 1.0
# issue with heat and power co-generation, natural gas, 1MW electrical, lean burn
# [('electricity production, natural gas, 10MW',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('gas turbine construction, 10MW electrical',
#   'technosphere',
#   1.25e-09,
#   'unit'),
#  ('market for natural gas, high pressure',
#   'technosphere',
#   0.298913043478261,
#   'cubic meter'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.6, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.000434782608695652, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.08695652173913e-05, 'kilogram'),
#  ('Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   'biosphere',
#   3.15217391304348e-16,
#   'kilogram'),
#  ('Mercury II', 'biosphere', 3.26086956521739e-10, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 4.89130434782608e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.08695652173913e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.00141304347826087, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 5.97826086956522e-06, 'kilogram'),
#  ('Water', 'biosphere', 0.000880987619047618, 'cubic meter'),
#  ('Water', 'biosphere', 0.0737669257142857, 'cubic meter'),
#  ('Water, cooling, unspecified natural origin',
#   'biosphere',
#   0.0746479133333333,
#   'cubic meter')] 3.6 0.0 in electricity production, natural gas, 10MW
#
# 0.0 3.6
# issue with electricity production, natural gas, 10MW
# [('heat and power co-generation, natural gas, 160kW electrical, lambda=1',
#   'production',
#   1.0,
#   'megajoule'),
#  ('heat and power co-generation unit construction, 160kW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   2.0524049856466197e-09,
#   'unit'),
#  ('heat and power co-generation unit construction, 160kW electrical, '
#   'components for electricity only',
#   'technosphere',
#   2.0524049856466197e-09,
#   'unit'),
#  ('heat and power co-generation unit construction, 160kW electrical, '
#   'components for heat only',
#   'technosphere',
#   2.0524049856466197e-09,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   1.2314429913879718e-05,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0016001307431743829,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0017809364768664035,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.000393252470780145,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.000831706374983295,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0009808711052792121,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.002004683572310279,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0021176871558677922,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0008158858732852432,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -1.2314429913879718e-05,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.02298693583924216, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 1.9703087862207562e-05, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.0262024928233098e-06, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 9.44106293397446e-06, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   8.209619942586479e-07,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 6.157214956939859e-06, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   6.157214956939859e-08,
#   'kilogram'),
#  ('Platinum', 'biosphere', 2.8733669799052588e-12, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 2.2576454842112793e-07, 'kilogram')] 1.0 0.0 in heat and power co-generation, natural gas, 160kW electrical, lambda=1
#
# 0.0 1.0
# issue with heat and power co-generation, natural gas, 160kW electrical, lambda=1
# [('petrol production, 15% ETBE additive by volume, with ethanol from biomass',
#   'production',
#   1.0,
#   'kilogram'),
#  ('market for ethyl tert-butyl ether', 'technosphere', 0.15, 'kilogram'),
#  ('market for petrol, low-sulfur',
#   'technosphere',
#   0.8341021741432204,
#   'kilogram'),
#  ('market for petrol, low-sulfur',
#   'technosphere',
#   0.01589782585677964,
#   'kilogram')] 16.2 0.0 in petrol production, 15% ETBE additive by volume, with ethanol from biomass
#
# 0.0 16.2
# issue with petrol production, 15% ETBE additive by volume, with ethanol from biomass
# [('heat and power co-generation, natural gas, 1MW electrical, lean burn',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('market for heat and power co-generation unit, 1MW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   8.363687106450946e-09,
#   'unit'),
#  ('market for heat and power co-generation unit, 1MW electrical, components '
#   'for electricity only',
#   'technosphere',
#   8.363687106450946e-09,
#   'unit'),
#  ('market for heat and power co-generation unit, 1MW electrical, components '
#   'for heat only',
#   'technosphere',
#   8.363687106450946e-09,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.00023670812565427165,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.006233067141341946,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0029687817034837055,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.05817987477243762,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.008267232382617819,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.12666568131146186,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -0.00023670812565427165,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.44185516788797335, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.0012624433368227815, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 3.9451354275711766e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 0.0006312216684113924, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   7.890270855142388e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.0005523189598599675, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.1835406282713565e-06,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 4.33964897032832e-06, 'kilogram')] 3.6 0.0 in heat and power co-generation, natural gas, 1MW electrical, lean burn
#
# 0.0 3.6
# issue with heat and power co-generation, natural gas, 1MW electrical, lean burn
# [('heat and power co-generation, natural gas, 1MW electrical, lean burn',
#   'production',
#   1.0,
#   'megajoule'),
#  ('market for heat and power co-generation unit, 1MW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('market for heat and power co-generation unit, 1MW electrical, components '
#   'for electricity only',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('market for heat and power co-generation unit, 1MW electrical, components '
#   'for heat only',
#   'technosphere',
#   3.942026516277273e-10,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   1.1156678819652644e-05,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.00029378090830245056,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.00013992651861814625,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0027421710801417273,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0003896564858741433,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.005970087929843551,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -1.1156678819652644e-05,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.02082580046335158, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 5.9502287038147395e-05, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.8594464699420989e-06, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 2.975114351907378e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   3.718892939884214e-06,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 2.6032250579189516e-05, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   5.5783394098263125e-08,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 2.0453911169363203e-07, 'kilogram')] 1.0 0.0 in heat and power co-generation, natural gas, 1MW electrical, lean burn
#
# 0.0 1.0
# issue with heat and power co-generation, natural gas, 1MW electrical, lean burn
# [('heat and power co-generation, natural gas, mini-plant 2KW electrical',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.00031728764477714257,
#   'kilogram'),
#  ('market for mini CHP plant, common components for heat+electricity',
#   'technosphere',
#   1.47009942080076e-06,
#   'unit'),
#  ('market for mini CHP plant, components for electricity only',
#   'technosphere',
#   1.47009942080076e-06,
#   'unit'),
#  ('market for mini CHP plant, components for heat only',
#   'technosphere',
#   1.47009942080076e-06,
#   'unit'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.041228194759146936,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.045886747839276536,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.010132352949281876,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.021429344168596147,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.025272650459703068,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.05165170727593692,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.05456330295101792,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.021021720774084807,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -0.00031728764477714257,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.5922702702506658, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.0013537606177158076, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 2.644063706476188e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 0.0004547789575139042, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   5.288127412952376e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.0002326776061699047, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.5864382238857127e-06,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 5.816940154247614e-06, 'kilogram')] 3.6 0.0 in heat and power co-generation, natural gas, mini-plant 2KW electrical
#
# 0.0 3.6
# issue with heat and power co-generation, natural gas, mini-plant 2KW electrical
# [('heat and power co-generation, natural gas, mini-plant 2KW electrical',
#   'production',
#   1.0,
#   'megajoule'),
#  ('market for lubricating oil',
#   'technosphere',
#   1.2277288388409676e-05,
#   'kilogram'),
#  ('market for mini CHP plant, common components for heat+electricity',
#   'technosphere',
#   5.688476953296482e-08,
#   'unit'),
#  ('market for mini CHP plant, components for electricity only',
#   'technosphere',
#   5.688476953296482e-08,
#   'unit'),
#  ('market for mini CHP plant, components for heat only',
#   'technosphere',
#   5.688476953296482e-08,
#   'unit'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.00032328912506512567,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.00015398114887335646,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0030176027925042496,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.000428794727070944,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.0065697410854689275,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -1.2277288388409676e-05,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.022917604991698055, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 5.2383097123881254e-05, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.0231073657008064e-06, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 1.7597446690053864e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   2.046214731401613e-06,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 9.003344818167102e-06, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   6.138644194204838e-08,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 2.250836204541774e-07, 'kilogram')] 1.0 0.0 in heat and power co-generation, natural gas, mini-plant 2KW electrical
#
# 0.0 1.0
# issue with heat and power co-generation, natural gas, mini-plant 2KW electrical
# [('heat and power co-generation, natural gas, 1MW electrical, lean burn',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('heat and power co-generation unit construction, 1MW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   8.363687106450946e-09,
#   'unit'),
#  ('heat and power co-generation unit construction, 1MW electrical, components '
#   'for electricity only',
#   'technosphere',
#   8.363687106450946e-09,
#   'unit'),
#  ('heat and power co-generation unit construction, 1MW electrical, components '
#   'for heat only',
#   'technosphere',
#   8.363687106450946e-09,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.00023670812565427165,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.20231463731134294,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -0.00023670812565427165,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.44185516788797335, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.0012624433368227815, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 3.9451354275711766e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 0.0006312216684113924, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   7.890270855142388e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.0005523189598599675, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.1835406282713565e-06,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 4.33964897032832e-06, 'kilogram')] 3.6 0.0 in heat and power co-generation, natural gas, 1MW electrical, lean burn
#
# 0.0 3.6
# issue with heat and power co-generation, natural gas, 1MW electrical, lean burn
# [('natural gas, burned in micro gas turbine, 100kWe',
#   'production',
#   1.0,
#   'megajoule'),
#  ('market for lubricating oil',
#   'technosphere',
#   2.3050673038487696e-07,
#   'kilogram'),
#  ('maintenance, micro gas turbine, 100kW electrical',
#   'technosphere',
#   4.5870839346590516e-08,
#   'unit'),
#  ('micro gas turbine production, 100kW electrical',
#   'technosphere',
#   9.174167869318103e-09,
#   'unit'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.01182085796844341,
#   'cubic meter'),
#  ("storage production, 10'000 l",
#   'technosphere',
#   3.8033610513504695e-09,
#   'unit'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -2.535574034233647e-07,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.02581675380310622, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 1.290837690155311e-05, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 4.610134607697539e-07, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 2.489472688156671e-06, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   2.7660807646185233e-07,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 1.4752430744632126e-05, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   2.3050673038487696e-07,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 2.535574034233647e-07, 'kilogram')] 1.0 0.0 in natural gas, burned in micro gas turbine, 100kWe
#
# 0.0 1.0
# issue with natural gas, burned in micro gas turbine, 100kWe
# [('sour gas, burned in gas turbine', 'production', 1.0, 'megajoule'),
#  ('market for gas turbine, 10MW electrical', 'technosphere', 3.37e-10, 'unit'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.0669, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.000139, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 2.5e-07, 'kilogram'),
#  ('Mercury II', 'biosphere', 2.78e-09, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 2.43e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   3.07e-06,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.000199, 'kilogram'),
#  ('Radon-222', 'biosphere', 0.00556, 'kilo Becquerel'),
#  ('Sulfur dioxide', 'biosphere', 0.00486, 'kilogram'),
#  ('Gas, natural', 'biosphere', 0.0278, 'Sm3')] 1.0 0.0 in sour gas, burned in gas turbine
#
# 0.0 1.0
# issue with sour gas, burned in gas turbine
# [('electricity production, natural gas, 10MW',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('gas turbine construction, 10MW electrical',
#   'technosphere',
#   1.25e-09,
#   'unit'),
#  ('market for natural gas, high pressure',
#   'technosphere',
#   0.298913043478261,
#   'cubic meter'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.608695652173913, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.000434782608695652, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.08695652173913e-05, 'kilogram'),
#  ('Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   'biosphere',
#   3.15217391304348e-16,
#   'kilogram'),
#  ('Mercury II', 'biosphere', 3.26086956521739e-10, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 4.89130434782608e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.08695652173913e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.00141304347826087, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 5.97826086956522e-06, 'kilogram'),
#  ('Water', 'biosphere', 0.000880987619047618, 'cubic meter'),
#  ('Water', 'biosphere', 0.0737669257142857, 'cubic meter'),
#  ('Water, cooling, unspecified natural origin',
#   'biosphere',
#   0.0746479133333333,
#   'cubic meter')] 3.6 0.0 in electricity production, natural gas, 10MW
#
# 0.0 3.6
# issue with electricity production, natural gas, 10MW
# [('heat and power co-generation, natural gas, 50kW electrical, lean burn',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('heat and power co-generation unit construction, 50kW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   1.5480443220523e-07,
#   'unit'),
#  ('heat and power co-generation unit construction, 50kW electrical, components '
#   'for electricity only',
#   'technosphere',
#   1.5480443220523e-07,
#   'unit'),
#  ('heat and power co-generation unit construction, 50kW electrical, components '
#   'for heat only',
#   'technosphere',
#   1.5480443220523e-07,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.0002780917943806526,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.03613510594684257,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.04021816876569484,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.008880661631003683,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.018782088966720432,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.022150615792273554,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.04527095900402452,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.04782287326580719,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.01842482097007086,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -0.0002780917943806526,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.519104682843887, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.001483156236696814, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 4.634863239677544e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 0.000741578118348407, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   9.269726479355088e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.0006488808535548587, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.390458971903261e-06,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 5.0983495636453115e-06, 'kilogram')] 3.6 0.0 in heat and power co-generation, natural gas, 50kW electrical, lean burn
#
# 0.0 3.6
# issue with heat and power co-generation, natural gas, 50kW electrical, lean burn
# [('electricity production, natural gas, 10MW',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('gas turbine construction, 10MW electrical',
#   'technosphere',
#   1.25e-09,
#   'unit'),
#  ('market for natural gas, high pressure',
#   'technosphere',
#   0.298913043478261,
#   'cubic meter'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.608695652173913, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.000434782608695652, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.08695652173913e-05, 'kilogram'),
#  ('Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   'biosphere',
#   3.15217391304348e-16,
#   'kilogram'),
#  ('Mercury II', 'biosphere', 3.26086956521739e-10, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 4.89130434782608e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.08695652173913e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.00141304347826087, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 5.97826086956522e-06, 'kilogram'),
#  ('Water', 'biosphere', 0.000880987619047618, 'cubic meter'),
#  ('Water', 'biosphere', 0.0737669257142857, 'cubic meter'),
#  ('Water, cooling, unspecified natural origin',
#   'biosphere',
#   0.0746479133333333,
#   'cubic meter')] 3.6 0.0 in electricity production, natural gas, 10MW
#
# 0.0 3.6
# issue with electricity production, natural gas, 10MW
# [('heat and power co-generation, natural gas, 50kW electrical, lean burn',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('market for heat and power co-generation unit, 50kW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   1.5480443220523e-07,
#   'unit'),
#  ('market for heat and power co-generation unit, 50kW electrical, components '
#   'for electricity only',
#   'technosphere',
#   1.5480443220523e-07,
#   'unit'),
#  ('market for heat and power co-generation unit, 50kW electrical, components '
#   'for heat only',
#   'technosphere',
#   1.5480443220523e-07,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.0002780917943806526,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.007322793930456632,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.003487813647141417,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.06835145911272972,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.00971259217016464,
#   'cubic meter'),
#  ('market for natural gas, low pressure',
# ...
#   'technosphere',
#   1.3429315111024843e-05,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.0017425740974828087,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   5.43122824059417e-05,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.00010512881078605971,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.00014049129654610605,
#   'kilogram'),
#  ('market for water, decarbonised',
#   'technosphere',
#   0.00027354481856918295,
#   'kilogram'),
#  ('market for wood ash mixture, pure',
#   'technosphere',
#   -0.0023320290091101174,
#   'kilogram'),
#  ('market for wood ash mixture, pure',
#   'technosphere',
#   -2.2990888344319473e-05,
#   'kilogram'),
#  ('market for wood ash mixture, pure',
#   'technosphere',
#   -0.0011184260694874092,
#   'kilogram'),
#  ('Acetaldehyde', 'biosphere', 4.005267046517457e-07, 'kilogram'),
#  ('Ammonia', 'biosphere', 1.1425032931191204e-05, 'kilogram'),
#  ('Arsenic ion', 'biosphere', 6.566183011280009e-09, 'kilogram'),
#  ('Benzene', 'biosphere', 5.358373495283504e-06, 'kilogram'),
#  ('Benzene, ethyl-', 'biosphere', 1.7664475647357498e-07, 'kilogram'),
#  ('Benzene, hexachloro-', 'biosphere', 4.239674968863438e-14, 'kilogram'),
#  ('Benzo(a)pyrene', 'biosphere', 2.9440932199413734e-09, 'kilogram'),
#  ('Bromine', 'biosphere', 3.939626134477333e-07, 'kilogram'),
#  ('Cadmium II', 'biosphere', 4.596118927169315e-09, 'kilogram'),
#  ('Calcium', 'biosphere', 3.841143848344468e-05, 'kilogram'),
#  ('Carbon dioxide, non-fossil', 'biosphere', 1.2915654789693325, 'kilogram'),
#  ('Carbon monoxide, non-fossil',
#   'biosphere',
#   4.1216970390016354e-05,
#   'kilogram'),
#  ('Chlorine', 'biosphere', 1.1818711058850613e-06, 'kilogram'),
#  ('Chromium III', 'biosphere', 2.6001582690924764e-08, 'kilogram'),
#  ('Chromium VI', 'biosphere', 2.626431368366675e-10, 'kilogram'),
#  ('Copper ion', 'biosphere', 1.4445184263362624e-07, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 1.5102011745217323e-05, 'kilogram'),
#  ('Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   'biosphere',
#   1.825311021230627e-13,
#   'kilogram'),
#  ('Fluorine', 'biosphere', 3.283007833349324e-07, 'kilogram'),
#  ('Formaldehyde', 'biosphere', 7.654759513054502e-07, 'kilogram'),
#  ('Hydrocarbons, aliphatic, alkanes, unspecified',
#   'biosphere',
#   5.358373495283504e-06,
#   'kilogram'),
#  ('Hydrocarbons, aliphatic, unsaturated',
#   'biosphere',
#   1.825311021230627e-05,
#   'kilogram'),
#  ('Lead II', 'biosphere', 1.634956559928786e-07, 'kilogram'),
#  ('Magnesium', 'biosphere', 2.37035232273401e-06, 'kilogram'),
#  ('Manganese II', 'biosphere', 1.1227984686634782e-06, 'kilogram'),
#  ('Mercury II', 'biosphere', 1.969813067238664e-09, 'kilogram'),
#  ('Methane, non-fossil', 'biosphere', 2.5554772658682193e-06, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   3.5917585859663673e-06,
#   'kilogram'),
#  ('Nickel II', 'biosphere', 3.939626134477333e-08, 'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.0005777990033054366, 'kilogram'),
#  ('PAH, polycyclic aromatic hydrocarbons',
#   'biosphere',
#   6.477072021703545e-08,
#   'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   0.0002643793368683216,
#   'kilogram'),
#  ('Phenol, pentachloro-', 'biosphere', 4.76932056888132e-11, 'kilogram'),
#  ('Phosphorus', 'biosphere', 1.9698130672386636e-06, 'kilogram'),
#  ('Potassium I', 'biosphere', 0.00015364324376505794, 'kilogram'),
#  ('Sodium', 'biosphere', 8.535828733937315e-06, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 1.6349565599287856e-05, 'kilogram'),
#  ('Toluene', 'biosphere', 1.7664475647357499e-06, 'kilogram'),
#  ('Water', 'biosphere', 3.307336398816167e-06, 'cubic meter'),
#  ('Zinc II', 'biosphere', 1.9698130672386636e-06, 'kilogram'),
#  ('m-Xylene', 'biosphere', 7.065706586652317e-07, 'kilogram'),
#  ('Water', 'biosphere', 0.003582170041069502, 'cubic meter'),
#  ('Carbon dioxide, in air', 'biosphere', 0.25973134112092844, 'kilogram')] 3.6 0.0 in ethanol production from sweet sorghum
#
# 0.0 3.6
# issue with ethanol production from sweet sorghum
# [('heat and power co-generation, natural gas, 160kW electrical, lambda=1',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('heat and power co-generation unit construction, 160kW electrical, common '
#   'components for heat+electricity',
#   'technosphere',
#   4.354530098868791e-08,
#   'unit'),
#  ('heat and power co-generation unit construction, 160kW electrical, '
#   'components for electricity only',
#   'technosphere',
#   4.354530098868791e-08,
#   'unit'),
#  ('heat and power co-generation unit construction, 160kW electrical, '
#   'components for heat only',
#   'technosphere',
#   4.354530098868791e-08,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   0.00026127180593212744,
#   'kilogram'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.22330923583942486,
#   'cubic meter'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -0.00026127180593212744,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.48770737107330503, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 0.00041803488949140416, 'kilogram'),
#  ('Dinitrogen monoxide', 'biosphere', 2.1772650494343955e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 0.00020030838454796458, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.7418120395475163e-05,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.00013063590296606372, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.3063590296606372e-06,
#   'kilogram'),
#  ('Platinum', 'biosphere', 6.096342138416288e-11, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 4.789983108755665e-06, 'kilogram')] 3.6 0.0 in heat and power co-generation, natural gas, 160kW electrical, lambda=1
#
# 0.0 3.6
# issue with heat and power co-generation, natural gas, 160kW electrical, lambda=1
# [('natural gas, burned in solid oxide fuel cell, with micro gas turbine, '
#   '180kWe, future',
#   'production',
#   1.0,
#   'megajoule'),
#  ('fuel cell production, solid oxide, with micro gas turbine, 180kW '
#   'electrical, future',
#   'technosphere',
#   3.793057711868825e-09,
#   'unit'),
#  ('market for lubricating oil',
#   'technosphere',
#   4.672607326215219e-08,
#   'kilogram'),
#  ('maintenance, solid oxide fuel cell, with micro gas turbine, 180kW '
#   'electrical, future',
#   'technosphere',
#   3.408254755592278e-08,
#   'unit'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.007047673191871112,
#   'cubic meter'),
#  ("storage production, 10'000 l",
#   'technosphere',
#   2.7018664715703297e-09,
#   'unit'),
#  ('market for tap water', 'technosphere', 5.772044344148212e-06, 'kilogram'),
#  ('market for waste mineral oil',
#   'technosphere',
#   -5.139868058836741e-08,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.0153921182510619, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 4.6726073262152194e-07, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 1.0994370179329927e-06, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   1.9240147813827373e-07,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 3.02345179931573e-06, 'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 1.511725899657865e-07, 'kilogram'),
#  ('Water', 'biosphere', 8.658066516222319e-10, 'cubic meter'),
#  ('Water', 'biosphere', 4.9062376925259805e-09, 'cubic meter')] 1.0 0.0 in natural gas, burned in solid oxide fuel cell, with micro gas turbine, 180kWe, future
#
# 0.0 1.0
# issue with natural gas, burned in solid oxide fuel cell, with micro gas turbine, 180kWe, future
# [('natural gas, burned in polymer electrolyte membrane fuel cell 2kWe, future',
#   'production',
#   1.0,
#   'kilowatt hour'),
#  ('fuel cell production, polymer electrolyte membrane, 2kW electrical, future',
#   'technosphere',
#   7.526392308831965e-06,
#   'unit'),
#  ('maintenance, polymer electrolyte membrane fuel cell 2kW electrical',
#   'technosphere',
#   0.00010537257843585944,
#   'unit'),
#  ('market for natural gas, low pressure',
#   'technosphere',
#   0.23273847752021326,
#   'cubic meter'),
#  ('storage production, 650 l mini CHP plant',
#   'technosphere',
#   5.298582363849854e-06,
#   'unit'),
#  ('Carbon dioxide, fossil', 'biosphere', 0.508300834904654, 'kilogram'),
#  ('Carbon monoxide, fossil', 'biosphere', 1.5430561059605567e-05, 'kilogram'),
#  ('Methane, fossil', 'biosphere', 3.630720249318957e-05, 'kilogram'),
#  ('NMVOC, non-methane volatile organic compounds',
#   'biosphere',
#   2.7230401869892175e-06,
#   'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 1.1799840810286611e-05, 'kilogram'),
#  ('Particulate Matter, < 2.5 um',
#   'biosphere',
#   1.8153601246594788e-09,
#   'kilogram'),
#  ('Sulfur dioxide', 'biosphere', 4.992240342813566e-06, 'kilogram')] 3.6 0.0 in natural gas, burned in polymer electrolyte membrane fuel cell 2kWe, future
#
# 0.0 3.6
# issue with natural gas, burned in polymer electrolyte membrane fuel cell 2kWe, future
# [('petrol production, 15% ETBE additive by volume, with ethanol from biomass',
#   'production',
#   1.0,
#   'kilogram'),
#  ('market for ethyl tert-butyl ether', 'technosphere', 0.15, 'kilogram'),
#  ('market for petrol, low-sulfur', 'technosphere', 0.85, 'kilogram')] 16.2 0.0 in petrol production, 15% ETBE additive by volume, with ethanol from biomass
#
# 0.0 16.2
# issue with petrol production, 15% ETBE additive by volume, with ethanol from biomass
# [('hydrogen production, auto-thermal reforming of natural gas, 25 bar',
#   'production',
#   1,
#   'kilogram'),
#  ('Carbon dioxide, fossil', 'biosphere', 8.986838104358853, 'kilogram'),
#  ('Nitrogen oxides', 'biosphere', 0.0029996721816189444, 'kilogram'),
#  ('Water, cooling, unspecified natural origin',
#   'biosphere',
#   0.38041197561668283,
#   'cubic meter'),
#  ('chemical factory construction, organics',
#   'technosphere',
#   5.348747161816524e-10,
#   'unit'),
#  ('market for aluminium oxide, metallurgical',
#   'technosphere',
#   0.0005327279999999999,
#   'kilogram'),
#  ('market for chromium oxide, flakes', 'technosphere', 3.6e-05, 'kilogram'),
#  ('market for copper oxide',
#   'technosphere',
#   0.00036239999999999997,
#   'kilogram'),
#  ('market for liquid storage tank, chemicals, organics',
#   'technosphere',
#   2.54628e-09,
#   'unit'),
#  ('market for magnesium oxide', 'technosphere', 2.796e-05, 'kilogram'),
#  ('market for molybdenum trioxide', 'technosphere', 1.668e-05, 'kilogram'),
#  ('market for nickel, class 1',
#   'technosphere',
#   0.00020292014459767036,
#   'kilogram'),
#  ('market for portafer', 'technosphere', 0.00031235999999999997, 'kilogram'),
#  ('market for quicklime, milled, packed', 'technosphere', 4.8e-05, 'kilogram'),
#  ('market for silica sand', 'technosphere', 1.1591999999999998e-05, 'kilogram'),
#  ('market for water, deionised', 'technosphere', 7.539015756360158, 'kilogram'),
#  ('market for zeolite, powder',
#   'technosphere',
#   0.0008829015460672572,
#   'kilogram'),
#  ('market for zinc oxide', 'technosphere', 0.00037140000000000003, 'kilogram'),
#  ('market group for electricity, high voltage',
#   'technosphere',
#   -0.6197526384772675,
#   'kilowatt hour'),
#  ('market group for natural gas, high pressure',
#   'technosphere',
#   4.356143282451772,
#   'cubic meter')] 120.0 0.0 in hydrogen production, auto-thermal reforming of natural gas, 25 bar
#
# 0.0 120.0
# issue with hydrogen production, auto-thermal reforming of natural gas, 25 bar
# [('hydrogen production, gaseous, 25 bar, from gasification of woody biomass in '
#   'entrained flow gasifier, at gasification plant',
#   'production',
#   1,
#   'kilogram'),
#  ('Carbon dioxide, non-fossil', 'biosphere', 21.1966, 'kilogram'),
#  ('market for liquid storage tank, chemicals, organics',
#   'technosphere',
#   2.54628e-09,
#   'unit'),
#  ('market for water, deionised', 'technosphere', 15.90552, 'kilogram'),
#  ('market for wood chips, wet, measured as dry mass',
#   'technosphere',
#   11.6966,
#   'kilogram'),
#  ('market group for electricity, low voltage',
#   'technosphere',
#   -0.01031,
#   'kilowatt hour'),
#  ('synthetic gas factory construction',
#   'technosphere',
#   5.348319914762801e-10,
#   'unit'),
#  ('treatment of wastewater, average, wastewater treatment',
#   'technosphere',
#   -0.012439,
#   'cubic meter')] 120.0 0.0 in hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, at gasification plant
#
# 0.0 120.0
# issue with hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, at gasification plant
# [('electricity production, wave energy converter',
#   'production',
#   1,
#   'kilowatt hour'),
#  ('wave energy converter platform production',
#   'technosphere',
#   1.6835016835016835e-08,
#   'unit')] 3.6 0.0 in electricity production, wave energy converter
#
# 0.0 3.6
# issue with electricity production, wave energy converter
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.9/site-packages/xarray/core/concat.py:229, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     228 try:
# --> 229     first_obj, objs = utils.peek_at(objs)
#     230 except StopIteration:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.9/site-packages/xarray/core/utils.py:188, in peek_at(iterable)
#     187 gen = iter(iterable)
# --> 188 peek = next(gen)
#     189 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 ndb = NewDatabase(
#       2         scenarios = scenarios,
#       3         source_db= "ecoinvent 3.9.1 cutoff",
#       4         source_version="3.9.1",
#       5         #source_type=source,
#       6         #source_file_path=f"/Users/romain/Documents/ecoinvent {ei}_cutoff_ecoSpold02/datasets" if source == "ecospold" else None, # <-- this is NEW
#       7         #source_version=ei,
#       8         key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
#       9         #system_model="cutoff",
#      10         #system_args=combinations[0]
#      11 )
#
# File ~/GitHub/premise/premise/ecoinvent_modification.py:592, in NewDatabase.__init__(self, scenarios, source_version, source_type, key, source_db, source_file_path, additional_inventories, system_model, system_args, use_cached_inventories, use_cached_database, external_scenarios, quiet, keep_uncertainty_data, gains_scenario, use_absolute_efficiency)
#     588         self.database[(scenario_label, col)] = np.nan
#     590     self.database[(scenario_label, c.comment)] = ""
# --> 592 self.iam_data = IAMData(list_data)
#     594 print("Done!")
#
# File ~/GitHub/premise/premise/ecoinvent_modification.py:388, in IAMData.__init__(self, list_data)
#     382 self.petrol_markets = xr.concat(
#     383     [d.petrol_markets for d in list_data], dim="scenario"
#     384 )
#     385 self.diesel_markets = xr.concat(
#     386     [d.diesel_markets for d in list_data], dim="scenario"
#     387 )
# --> 388 self.gas_markets = xr.concat(
#     389     [d.gas_markets for d in list_data if d.gas_markets is not None], dim="scenario"
#     390 )
#     391 self.hydrogen_markets = xr.concat(
#     392     [d.hydrogen_markets for d in list_data], dim="scenario"
#     393 )
#     394 self.cement_markets = xr.concat(
#     395     [d.cement_markets for d in list_data], dim="scenario"
#     396 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.9/site-packages/xarray/core/concat.py:231, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     229     first_obj, objs = utils.peek_at(objs)
#     230 except StopIteration:
# --> 231     raise ValueError("must supply at least one object to concatenate")
#     233 if compat not in _VALID_COMPAT:
#     234     raise ValueError(
#     235         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     236     )
#
# ValueError: must supply at least one object to concatenate

# %%
#ndb.update_electricity()
ndb.update_metals()

# %%
ndb.write_db_to_brightway("metal_test")
# Out:
# Write new database(s) to Brightway2.
# Prepare database 1.
# - check for duplicates...
# - check for values format...
# - relinking exchanges...
# Done!
# Database metal_test already exists: it will be overwritten.
# Vacuuming database
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:28
# Title: Writing activities to SQLite3 database:
#   Started: 07/15/2023 14:22:18
#   Finished: 07/15/2023 14:22:47
#   Total time elapsed: 00:00:28
#   CPU %: 97.90
#   Memory %: 13.68
# Created database: metal_test
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.

# %%
('market for platinum', 'platinum', 'World', 'kilogram') in ndb.modified_datasets[("image", "SSP2-Base", 2050)]["created"]
# Out:
# True

# %%
ndb.scenarios[0].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 ndb.cache
#
# AttributeError: 'NewDatabase' object has no attribute 'cache'

# %%
for ds in ndb.scenarios[0]["database"]:
    for e in ds["exchanges"]:
        if e["name"] == "market for platinum" and e["product"] == "platinum":
            print(ds["name"], ds["location"], e["name"], e["location"])
# Out:
# petrol production, unleaded, petroleum refinery operation IN market for platinum GLO
# pitch production, petroleum refinery operation RoW market for platinum World
# reformate production, petroleum refinery operation RoW market for platinum World
# sulfur production, petroleum refinery operation PE market for platinum GLO
# petroleum coke production, petroleum refinery operation RoW market for platinum World
# heavy fuel oil production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation IN market for platinum GLO
# base oil production, petroleum refinery operation BR market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation CO market for platinum GLO
# white spirit production, petroleum refinery operation RoW market for platinum World
# white spirit production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# internal combustion engine production, passenger car GLO market for platinum World
# light fuel oil production, petroleum refinery operation IN market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation PE market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation RoW market for platinum World
# reformate production, petroleum refinery operation ZA market for platinum GLO
# catalytic converter production, oxidation, 20 litre RoW market for platinum World
# sulfur production, petroleum refinery operation IN market for platinum GLO
# electric parts production, heat and power co-generation unit, 160kW electrical RER market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation PE market for platinum GLO
# petroleum slack wax production, petroleum refinery operation BR market for platinum GLO
# fuel cell production, polymer electrolyte membrane, 2kW electrical, future CH market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation BR market for platinum GLO
# motor scooter production RoW market for platinum World
# naphtha production, petroleum refinery operation CO market for platinum GLO
# fuel cell production, polymer electrolyte membrane, 2kW electrical, future RoW market for platinum World
# refinery gas production, petroleum refinery operation IN market for platinum GLO
# petroleum slack wax production, petroleum refinery operation IN market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation CO market for platinum GLO
# kerosene production, petroleum refinery operation CO market for platinum GLO
# pitch production, petroleum refinery operation IN market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation IN market for platinum GLO
# reformate production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# motor scooter production RER market for platinum GLO
# light fuel oil production, petroleum refinery operation PE market for platinum GLO
# heavy fuel oil production, petroleum refinery operation RoW market for platinum World
# white spirit production, petroleum refinery operation ZA market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# reformate production, petroleum refinery operation PE market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# light fuel oil production, petroleum refinery operation RoW market for platinum World
# C3 hydrocarbon production, mixture, petroleum refinery operation BR market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# nuclear power plant construction, pressure water reactor 650MW CA-QC market for platinum GLO
# heavy fuel oil production, petroleum refinery operation PE market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# petrol production, unleaded, petroleum refinery operation BR market for platinum GLO
# nuclear power plant construction, pressure water reactor 650MW RoW market for platinum World
# ascorbic acid production RoW market for platinum World
# kerosene production, petroleum refinery operation IN market for platinum GLO
# ascorbic acid production RER market for platinum GLO
# reformate production, petroleum refinery operation CO market for platinum GLO
# kerosene production, petroleum refinery operation RoW market for platinum World
# catalytic converter production, oxidation, 20 litre RER market for platinum GLO
# naphtha production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation IN market for platinum GLO
# white spirit production, petroleum refinery operation IN market for platinum GLO
# diesel production, petroleum refinery operation BR market for platinum GLO
# base oil production, petroleum refinery operation CO market for platinum GLO
# petroleum coke production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation RoW market for platinum World
# sulfur production, petroleum refinery operation BR market for platinum GLO
# electric parts production, heat and power co-generation unit, 160kW electrical RoW market for platinum World
# sodium perchlorate production GLO market for platinum World
# hydrogen production, gaseous, petroleum refinery operation ZA market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation BR market for platinum GLO
# refinery gas production, petroleum refinery operation ZA market for platinum GLO
# pitch production, petroleum refinery operation CO market for platinum GLO
# refinery gas production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# catalytic converter production, three-way, 19.1l RoW market for platinum World
# maintenance, polymer electrolyte membrane fuel cell 2kW electrical CH market for platinum GLO
# electric parts production, mini CHP plant CH market for platinum GLO
# fuel cell production, stack polymer electrolyte membrane, 2kW electrical, future RoW market for platinum World
# petrol production, unleaded, petroleum refinery operation PE market for platinum GLO
# petroleum slack wax production, petroleum refinery operation ZA market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation ZA market for platinum GLO
# white spirit production, petroleum refinery operation BR market for platinum GLO
# light fuel oil production, petroleum refinery operation ZA market for platinum GLO
# white spirit production, petroleum refinery operation PE market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation CO market for platinum GLO
# light fuel oil production, petroleum refinery operation BR market for platinum GLO
# heavy fuel oil production, petroleum refinery operation IN market for platinum GLO
# fuel cell production, stack polymer electrolyte membrane, 2kW electrical, future CH market for platinum GLO
# sulfur production, petroleum refinery operation ZA market for platinum GLO
# white spirit production, petroleum refinery operation CO market for platinum GLO
# refinery gas production, petroleum refinery operation CO market for platinum GLO
# petroleum coke production, petroleum refinery operation ZA market for platinum GLO
# base oil production, petroleum refinery operation PE market for platinum GLO
# diesel production, petroleum refinery operation PE market for platinum GLO
# naphtha production, petroleum refinery operation IN market for platinum GLO
# heavy fuel oil production, petroleum refinery operation BR market for platinum GLO
# petroleum slack wax production, petroleum refinery operation CO market for platinum GLO
# maintenance, polymer electrolyte membrane fuel cell 2kW electrical RoW market for platinum World
# refinery gas production, petroleum refinery operation RoW market for platinum World
# pitch production, petroleum refinery operation ZA market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation IN market for platinum GLO
# pitch production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# pitch production, petroleum refinery operation PE market for platinum GLO
# power saw production, with catalytic converter GLO market for platinum World
# kerosene production, petroleum refinery operation ZA market for platinum GLO
# pitch production, petroleum refinery operation BR market for platinum GLO
# naphtha production, petroleum refinery operation ZA market for platinum GLO
# petroleum slack wax production, petroleum refinery operation RoW market for platinum World
# base oil production, petroleum refinery operation RoW market for platinum World
# liquefied petroleum gas production, petroleum refinery operation CO market for platinum GLO
# diesel production, petroleum refinery operation RoW market for platinum World
# C3 hydrocarbon production, mixture, petroleum refinery operation Europe without Switzerland market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# light fuel oil production, petroleum refinery operation CO market for platinum GLO
# base oil production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# base oil production, petroleum refinery operation IN market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation RoW market for platinum World
# petroleum slack wax production, petroleum refinery operation PE market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation PE market for platinum GLO
# light fuel oil production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation CO market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation BR market for platinum GLO
# heavy fuel oil production, petroleum refinery operation CO market for platinum GLO
# reformate production, petroleum refinery operation BR market for platinum GLO
# reformate production, petroleum refinery operation IN market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation IN market for platinum GLO
# control cabinet production, heat and power co-generation unit, 160kW electrical RER market for platinum GLO
# petroleum slack wax production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# control cabinet production, heat and power co-generation unit, 160kW electrical RoW market for platinum World
# C3 hydrocarbon production, mixture, petroleum refinery operation PE market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# sulfur production, petroleum refinery operation RoW market for platinum World
# diesel production, petroleum refinery operation ZA market for platinum GLO
# diesel production, petroleum refinery operation CO market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation ZA market for platinum GLO
# kerosene production, petroleum refinery operation BR market for platinum GLO
# refinery gas production, petroleum refinery operation PE market for platinum GLO
# platinum to generic market for metal catalyst for catalytic converter GLO market for platinum World
# petrol production, unleaded, petroleum refinery operation ZA market for platinum GLO
# naphtha production, petroleum refinery operation BR market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation RoW market for platinum World
# base oil production, petroleum refinery operation ZA market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation Europe without Switzerland market for platinum GLO
# diesel production, petroleum refinery operation IN market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation Europe without Switzerland market for platinum GLO
# naphtha production, petroleum refinery operation PE market for platinum GLO
# catalytic converter production, three-way, 19.1l RER market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation ZA market for platinum GLO
# electric parts production, mini CHP plant RoW market for platinum World
# refinery gas production, petroleum refinery operation BR market for platinum GLO
# heavy fuel oil production, petroleum refinery operation ZA market for platinum GLO
# diesel production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# sulfur production, petroleum refinery operation CO market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation Europe without Switzerland market for platinum GLO
# naphtha production, petroleum refinery operation RoW market for platinum World
# kerosene production, petroleum refinery operation PE market for platinum GLO
# kerosene production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# petrol production, unleaded, petroleum refinery operation Europe without Switzerland market for platinum GLO
# petrol production, unleaded, petroleum refinery operation RoW market for platinum World
# diesel production, low-sulfur, petroleum refinery operation RoW market for platinum World
# petrol production, unleaded, petroleum refinery operation CO market for platinum GLO
# sulfur production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# electrolyzer production, 1MWe, PEM, Stack RER market for platinum GLO
# hydrogenation of hydrogen RER market for platinum GLO
# dehydrogenation of hydrogen RER market for platinum GLO
# fuel cell stack production, 1 kWe, proton exchange membrane (PEM) GLO market for platinum World
# market for platinum World market for platinum World

# %%
import pprint
for ds in ndb.scenarios[0]["database"]:
    if ds["name"].lower() == "lithium carbonate, precipitated":
        print(ds["name"], ds["location"])

# %%
from premise.activity_maps import InventorySet
inv = InventorySet(ndb.database, "3.9")

# %%
inv.generate_metals_map()
# Out:
# {'Dysprosium': {'Dysprosium'},
#  'Neodymium': {'Neodymium, 4% in bastnasite, 0.4% in crude ore'},
#  'Nickel': {'Nickel',
#   'Nickel, 1.13% in sulfide, Ni 0.76% and Cu 0.76% in crude ore',
#   'Nickel, 1.98% in silicates, 1.04% in crude ore',
#   'Nickel, Ni 2.5E+0%, in mixed ore'},
#  'Manganese': {'Manganese',
#   'Manganese, 35.7% in sedimentary deposit, 14.2% in crude ore'},
#  'Yttrium': {'Yttrium'},
#  'Vanadium': {'Vanadium'},
#  'Cobalt': {'Cobalt', 'Cobalt, Co 5.0E-2%, in mixed ore'},
#  'Lithium': {'Lithium', 'Lithium, 0.15% in brine'},
#  'Sulfur': {'Sulfur'},
#  'Platinum': {'Platinum', 'Platinum, Pt 4.7E-7%, in mixed ore'},
#  'Cerium': {'Cerium', 'Cerium, 24% in bastnasite, 2.4% in crude ore'},
#  'Lanthanum': {'Lanthanum',
#   'Lanthanum, 7.2% in bastnasite, 0.72% in crude ore'},
#  'Zirconium': {'Zirconium', 'Zirconium, 50% in zircon, 0.39% in crude ore'},
#  'Gadolinium': {'Gadolinium',
#   'Gadolinium, 0.15% in bastnasite, 0.015% in crude ore'},
#  'Scandium': {'Scandium'},
#  'Strontium': {'Strontium'},
#  'Potassium': {'Potassium'},
#  'Iridium': {'Iridium'},
#  'Silver': {'Silver',
#   'Silver, 0.007% in sulfide, Ag 0.004%, Pb, Zn, Cd, In',
#   'Silver, 0.01% in crude ore',
#   'Silver, 3.2ppm in sulfide, Ag 1.2ppm, Cu and Te, in crude ore',
#   'Silver, Ag 1.5E-4%, Au 6.8E-4%, in ore',
#   'Silver, Ag 1.5E-5%, Au 5.4E-4%, in ore',
#   'Silver, Ag 1.8E-6%, in mixed ore',
#   'Silver, Ag 2.1E-4%, Au 2.1E-4%, in ore',
#   'Silver, Ag 4.2E-3%, Au 1.1E-4%, in ore',
#   'Silver, Ag 4.6E-5%, Au 1.3E-4%, in ore',
#   'Silver, Ag 5.4E-3%, in mixed ore',
#   'Silver, Ag 7.6E-5%, Au 9.7E-5%, in ore',
#   'Silver, Ag 9.7E-4%, in mixed ore'},
#  'Germanium': {'Germanium'},
#  'Indium': {'Indium', 'Indium, 0.005% in sulfide, In 0.003%, Pb, Zn, Ag, Cd'},
#  'Gallium': {'Gallium', 'Gallium, 0.014% in bauxite'},
#  'Selenium': {'Selenium'},
#  'Cadmium': {'Cadmium', 'Cadmium, 0.30% in sulfide, Cd 0.18%, Pb, Zn, Ag, In'},
#  'Tellurium': {'Tellurium',
#   'Tellurium, 0.5ppm in sulfide, Te 0.2ppm, Cu and Ag, in crude ore'}}

# %%
inv.generate_powerplant_map()
# Out:
# {'Biomass CHP': {'heat and power co-generation, wood chips, 2000 kW',
#   'heat and power co-generation, wood chips, 2000 kW, state-of-the-art 2014',
#   'heat and power co-generation, wood chips, 6667 kW',
#   'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014',
#   'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014, renewable energy products'},
#  'Biomass CHP CCS': {'electricity production, at co-generation power plant/wood, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/wood, post, pipeline 400km, storage 3000m'},
#  'Biomass ST': {'electricity production, at wood burning power plant 20 MW, truck 25km, no CCS'},
#  'Biomass IGCC CCS': {'electricity production, at BIGCC power plant, pre, pipeline 200km, storage 1000m',
#   'electricity production, at wood burning power plant 20 MW, truck 25km, post, pipeline 200km, storage 1000m'},
#  'Biomass IGCC': {'electricity production, at BIGCC power plant, no CCS'},
#  'Coal PC': {'electricity production, hard coal',
#   'electricity production, hard coal, at coal mine power plant',
#   'electricity production, hard coal, conventional',
#   'electricity production, hard coal, supercritical',
#   'electricity production, lignite'},
#  'Coal IGCC': {'electricity production, at power plant/hard coal, IGCC, no CCS',
#   'electricity production, at power plant/lignite, IGCC, no CCS'},
#  'Coal PC CCS': {'electricity production, at power plant/hard coal, post, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/lignite, post, pipeline 200km, storage 1000m'},
#  'Coal IGCC CCS': {'electricity production, at power plant/hard coal, pre, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/lignite, pre, pipeline 200km, storage 1000m'},
#  'Coal CHP': {'heat and power co-generation, hard coal',
#   'heat and power co-generation, lignite'},
#  'Coal CHP CCS': {'electricity production, at co-generation power plant/hard coal, oxy, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/hard coal, oxy, pipeline 400km, storage 3000m',
#   'electricity production, at co-generation power plant/hard coal, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/hard coal, post, pipeline 400km, storage 1000m',
#   'electricity production, at co-generation power plant/hard coal, post, pipeline 400km, storage 3000m'},
#  'Gas OC': {'electricity production, natural gas, conventional power plant'},
#  'Gas CC': {'electricity production, natural gas, combined cycle power plant'},
#  'Gas CHP': {'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical',
#   'heat and power co-generation, natural gas, conventional power plant, 100MW electrical'},
#  'Gas CHP CCS': {'electricity production, at co-generation power plant/natural gas, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/natural gas, pre, pipeline 200km, storage 1000m'},
#  'Gas CC CCS': {'electricity production, at power plant/natural gas, post, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/natural gas, post, pipeline 400km, storage 1000m',
#   'electricity production, at power plant/natural gas, post, pipeline 400km, storage 3000m',
#   'electricity production, at power plant/natural gas, pre, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/natural gas, pre, pipeline 400km, storage 3000m'},
#  'Geothermal': {'electricity production, deep geothermal'},
#  'Hydro': {'electricity production, hydro, reservoir, alpine region',
#   'electricity production, hydro, reservoir, alpine region, renewable energy products',
#   'electricity production, hydro, reservoir, non-alpine region',
#   'electricity production, hydro, reservoir, tropical region',
#   'electricity production, hydro, run-of-river',
#   'electricity production, hydro, run-of-river, renewable energy products'},
#  'Nuclear': {'electricity production, nuclear, boiling water reactor',
#   'electricity production, nuclear, pressure water reactor',
#   'electricity production, nuclear, pressure water reactor, heavy water moderated'},
#  'Nuclear_EPR': {'electricity production, Evolutionary Power Reactor (EPR)'},
#  'Nuclear_SMR': {'electricity production, Small Modular Reactor (SMR)'},
#  'Oil ST': {'electricity production, oil'},
#  'Oil CC': {'electricity production, oil'},
#  'Oil CC CCS': {'electricity production, at co-generation power plant/oil, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/oil, pre, pipeline 200km, storage 1000m'},
#  'Oil CHP': {'heat and power co-generation, oil'},
#  'Oil CHP CCS': {'electricity production, at co-generation power plant/oil, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/oil, pre, pipeline 200km, storage 1000m'},
#  'Solar CSP': {'electricity production, solar thermal parabolic trough, 50 MW',
#   'electricity production, solar tower power plant, 20 MW'},
#  'Solar PV Centralized': {'electricity production, photovoltaic, commercial'},
#  'Solar PV Residential': {'electricity production, photovoltaic, residential'},
#  'Wind Onshore': {'electricity production, wind, 1-3MW turbine, onshore',
#   'electricity production, wind, 1-3MW turbine, onshore, renewable energy products',
#   'electricity production, wind, <1MW turbine, onshore',
#   'electricity production, wind, <1MW turbine, onshore, renewable energy products',
#   'electricity production, wind, >3MW turbine, onshore',
#   'electricity production, wind, >3MW turbine, onshore, renewable energy products'},
#  'Wind Offshore': {'electricity production, wind, 1-3MW turbine, offshore'},
#  'Wave': {'electricity production, wave energy converter'}}

# %%
inv.generate_daccs_map()
# Out:
# {'dac_solvent': {'carbon dioxide, captured from atmosphere, with a solvent-based direct air capture system, 1MtCO2'},
#  'dac_sorbent': {'carbon dioxide, captured from atmosphere, with a sorbent-based direct air capture system, 100ktCO2'},
#  'daccs_solvent': {'carbon dioxide, captured from atmosphere and stored, with a solvent-based direct air capture system, 1MtCO2'},
#  'daccs_sorbent': {'carbon dioxide, captured from atmosphere and stored, with a sorbent-based direct air capture system, 100ktCO2'}}

# %%
ndb.write_db_to_brightway("test_metals")
# Out:
# Write new database(s) to Brightway2.
# Prepare database 1.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:31
# Title: Writing activities to SQLite3 database:
#   Started: 06/19/2023 12:11:07
#   Finished: 06/19/2023 12:11:38
#   Total time elapsed: 00:00:31
#   CPU %: 86.50
#   Memory %: 11.62
# Created database: test_metals
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.

# %%
products = [
    'lightweighting, glider',
    'auxilliary battery inputs, for road vehicle',
    'battery cell, Li-ion, NMC622',
    'auxilliary electronics inputs, for fuel cell electric vehicle',
    'auxilliary material inputs, for fuel cell electric vehicle',
    'fuel cell stack, for fuel cell electric vehicle',
    'carbon fiber, weaved',
    'tank liner, polyethylene, high density',
    'transformer and rectifier unit, for electrolyser',
    'fuel tank, for diesel road vehicle',
    'fuel tank, for compressed hydrogen gas, 700bar',
    'fuel tank, for compressed hydrogen gas, 700bar',
    'fuel tank, for compressed hydrogen gas, 700bar',
    'fuel tank, for compressed natural gas, 200 bar',
    'charger, level 3, plugin, 200 kW, for electric vehicle',
    'gearbox, for lorry',
    'transmission, for lorry',
    'suspension, for lorry',
    'power electronics, for lorry',
    'auxilliary material inputs, for electric lorry',
    'retarder, for lorry',
    'cabin, for lorry',
    'frame, blanks and saddle, for lorry',
    'tires and wheels, for lorry',
    'auxilliary material inputs, for hydrid electric lorry',
    'exhaust system, for lorry',
    'internal combustion engine, for lorry',
    'lead acid battery, for lorry',
    'charger, level 3, with pantograph, 450 kW, for electric vehicle',
    'overhead lines, for electric vehicle',
    'battery cell, Li-ion, LTO',
    'charging station, 3kW',
    'battery cell,  Li-ion, LFP',
    'battery cell, Li-ion, NCA',
    'assembly operation, for lorry'
]

print(len(products))

acts = [a for a in bw.Database("brian") if a["reference product"] in products]

# %%
len(acts)

# %%
[a["reference product"] for a in acts]

# %%
import bw2data
bw2io.BW2Package.export_obj(obj=bw.Database("brian"), filename="db_for_brian.bw2package")

# %%
import bw2data
bw2io.BW2Package.import_file("db_for_brian.bw2package")

# %%
fp = "/Users/romain/Library/Application Support/Brightway3/ei39.f1469ad5eb0a071dc60323f6e0fce980/output/lci-brian.xlsx"
import bw2io

i = bw2io.ExcelImporter(fp)
i.apply_strategies()

# %%
ei_acts = list(set([(a["name"], a["reference product"]) for a in bw.Database("ecoinvent 3.9.1 cutoff")]))
print(len(ei_acts))

# %%
for ds in i.data:
    if (ds["name"], ds["reference product"]) in ei_acts:
        i.data.remove(ds)

# %%
for ds in i.data:
    if (ds["name"], ds["reference product"]) not in ei_acts:
        print(ds["name"])

# %%
len(i.data)

# %%
for ds in i.data:
    print(ds["name"])

# %%
i.match_database(fields=["name", "unit", "location"])
i.match_database("ecoinvent 3.9.1 cutoff", fields=["name", "reference product", "location", "unit"])
i.match_database("biosphere3", fields=["name", "categories", "unit"])

# %%
i.statistics()

# %%
list(i.unlinked)[-1]

# %%
bw.get_activity(('brian', '360c5e612a154ebb8cee2650bcc1bc75_copy1'))

# %%
for f in bw.Database("biosphere3"):
    if f["code"] == "e030108f-2125-4bcb-a73b-ad72130fcca3":
        print(f)

# %%
bw.projects.set_current("ei39")

# %%
l = []

for f in bw.Database("biosphere3"):
    l.append([f["name"], f["categories"][0], f["categories"][1] if len(f["categories"])>1 else "unspecified", f["unit"], f["code"]])

# %%
import csv

with open("flows_biosphere_39.csv", "w", newline="", ) as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerows(l)

# %%
ndb.scenarios[1]["iam data"].fuel_markets.sel(region="NEU").variables.values

# %%
import numpy as np
for ds in ndb.scenarios[1]["database"]:
    if ds["name"] == ("carbon dioxide, captured from atmosphere, with a solvent-based direct air capture system, 1MtCO2, with waste heat, and grid electricity",
                            "carbon dioxide, captured from atmosphere"):
            print(ds["name"], ds["location"])

# %%
for ds in ndb.scenarios[1]["database"]:
    if "carbon dioxide, captured" in ds["name"]:
        print(ds["name"], ds["location"])

# %%
ndb.scenarios[0]["iam data"].fuel_markets.sel(region="WEU", year=2050)

# %%
ndb.scenarios[0]["iam data"].fuel_markets.sel(region="WEU")

# %%
ndb.update_electricity()

# %%
ndb.scenarios[0]["iam data"].fuel_markets

# %%
ndb.generate_scenario_report()

# %%
ndb.generate_change_report()

# %%
ndb.update_all()

# %%
ndb.generate_scenario_report()

# %%
ndb.generate_change_report()

# %%
ndb.scenarios[0]["iam data"].gains_data_IAM

# %%
ndb.update_all()

# %%
ndb.write_db_to_brightway(["test_dac", "test_dac2"])

# %%
from premise.geomap import Geomap

# %%
Geomap()

# %%
Geomap(model="remind").geo.keys()

# %%
ndb.scenarios[0]["iam data"].carbon_capture_rate.sel(variables="steel")

# %%
for ds in ndb.scenarios[0]["database"]:
    for e in ds["exchanges"]:
        if e["name"].startswith("CO2 capture, at cement production plant"):
            print(e["name"], e.get("location"), e["amount"])
            print(ds["name"])
            print("--------------------")
