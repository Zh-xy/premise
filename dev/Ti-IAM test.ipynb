# %%
from premise import *
import bw2data
bw2data.projects.set_current("ei39")

# %%
scenarios = [
    {"model":"tiam", "pathway":"SSP2-RCP19", "year":2020, "filepath": "/Users/romain/Downloads/Scenario Files/Production volumes & efficiencies"}, # optimistic renewable scenario, 2.3-2.8 °C
]

# %%
ndb = NewDatabase(
        scenarios=scenarios,
        source_db="ecoinvent 3.9.1 cutoff",
        source_version="3.9.1",
        use_absolute_efficiency=True,
            #source_type="ecospold",
        #source_file_path=f"/Users/romain/Documents/ecoinvent 3.9.1_cutoff_ecoSpold02/datasets", # <-- this is NEW
        #key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
        #system_model="cutoff",
        #system_args=combinations[0]
)
# Out:
# premise v.(1, 8, 2, 'dev2')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Disable multiprocessing?
# NewDatabase(..., use_multiprocessing=False)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|█████████████████████████████████| 21238/21238 [00:00<00:00, 227675.26it/s]
# Adding exchange data to activities
# 100%|████████████████████████████████| 674593/674593 [00:47<00:00, 14117.27it/s]
# Filling out exchange data
# 100%|███████████████████████████████████| 21238/21238 [00:02<00:00, 7139.05it/s]
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Extracted 1 worksheets in 0.16 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 7 worksheets in 0.04 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.04 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.59 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Extracted 1 worksheets in 0.07 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | carbon dioxide, captured at ce | carbon dioxide, captured and r |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+----------------------+----------+--------------------------------+
# |              Name              |  Reference product   | Location |              File              |
# +--------------------------------+----------------------+----------+--------------------------------+
# | methanol distillation, hydroge |  methanol, purified  |   RER    | lci-synfuels-from-methanol-fro |
# | methanol synthesis, hydrogen f | methanol, unpurified |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+----------------------+----------+--------------------------------+
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.04 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 5 worksheets in 0.22 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.04 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.12 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 2 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.07 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Data cached. It is advised to restart your workflow at this point.
# This allows premise to use the cached data instead, which results in
# a faster workflow.
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# Reading /Users/romain/Downloads/Scenario Files/Production volumes & efficiencies/tiam_SSP2-RCP19.xlsx as excel file
# The following variables are missing from the IAM file:
# +--------------------------------------+
# |               Variable               |
# +--------------------------------------+
# | Secondary Energy|Electricity|Storage |
# +--------------------------------------+
# The following variables are missing from the IAM file:
# +-------------------------------------+
# |               Variable              |
# +-------------------------------------+
# |   Primary Energy|Biomass|Residues   |
# | Primary Energy|Biomass|Energy Crops |
# +-------------------------------------+
# The following variables are missing from the IAM file:
# +--------------------------------------+
# |               Variable               |
# +--------------------------------------+
# |   Primary Energy|Biomass|Residues    |
# | Primary Energy|Biomass|Energy Crops  |
# | Secondary Energy|Electricity|Storage |
# +--------------------------------------+
# Done!

# %%
ndb.update_electricity()
# Out:
# /////////////////////////// ELECTRICITY ////////////////////////////
# Warning: No activities found for Biomass CHP (existing) -- revise mapping.
# Warning: No activities found for Coal USC -- revise mapping.
# Warning: No activities found for Coal USC CCS -- revise mapping.
# Warning: No activities found for Gas GT -- revise mapping.
# {'Biogas CHP': {'heat and power co-generation, biogas, gas engine',
#                 'heat and power co-generation, biogas, gas engine, renewable '
#                 'energy products'},
#  'Biomass CHP': {'heat and power co-generation, wood chips, 2000 kW',
#                  'heat and power co-generation, wood chips, 2000 kW, '
#                  'state-of-the-art 2014',
#                  'heat and power co-generation, wood chips, 6667 kW',
#                  'heat and power co-generation, wood chips, 6667 kW, '
#                  'state-of-the-art 2014'},
#  'Biomass CHP (existing)': {'heat and power co-generation, existing, wood '
#                             'chips'},
#  'Biomass IGCC': {'electricity production, at biomass-fired IGCC power plant'},
#  'Biomass IGCC CCS': {'electricity production, at biomass-fired IGCC power '
#                       'plant, pre, pipeline 200km, storage 1000m'},
#  'Biomass MSW': {'treatment of municipal solid waste, incineration'},
#  'Biomass ST': {'electricity production, at wood burning power plant'},
#  'Biomass ST CCS': {'electricity production, at wood burning power plant, '
#                     'post, pipeline 200km, storage 1000m'},
#  'Coal CF 50-50': {'electricity production, at co-firing wood and coal power '
#                    'plant, 50-50'},
#  'Coal CF 80-20': {'electricity production, at co-firing wood and coal power '
#                    'plant, 80-20'},
#  'Coal CHP': {'heat and power co-generation, hard coal',
#               'heat and power co-generation, lignite'},
#  'Coal IGCC': {'electricity production, at hard coal-fired IGCC power plant',
#                'electricity production, at lignite-fired IGCC power plant'},
#  'Coal IGCC CCS': {'electricity production, at hard coal-fired IGCC power '
#                    'plant, pre, pipeline 200km, storage 1000m',
#                    'electricity production, at lignite-fired IGCC power plant, '
#                    'pre, pipeline 200km, storage 1000m'},
#  'Coal PC': {'electricity production, hard coal',
#              'electricity production, hard coal, conventional',
#              'electricity production, lignite'},
#  'Coal SC': {'electricity production, hard coal, supercritical'},
#  'Coal USC': {'electricity production, hard coal, ultra-supercritical'},
#  'Coal USC CCS': {'electricity production, at hard coal-fired power plant, '
#                   'ultra-super critical, oxy, pipeline 200km, storage 1000m'},
#  'Gas CC': {'electricity production, natural gas, combined cycle power plant'},
#  'Gas CC CCS': {'electricity production, at natural gas-fired combined cycle '
#                 'power plant, post, pipeline 200km, storage 1000m'},
#  'Gas CHP': {'heat and power co-generation, natural gas, combined cycle power '
#              'plant, 400MW electrical',
#              'heat and power co-generation, natural gas, conventional power '
#              'plant, 100MW electrical'},
#  'Gas GT': {'electricity production, natural gas, gas turbine, conventional '
#             'power plant'},
#  'Gas OC': {'electricity production, natural gas, conventional power plant'},
#  'Geothermal': {'electricity production, deep geothermal'},
#  'Hydro': {'electricity production, hydro, reservoir, alpine region',
#            'electricity production, hydro, reservoir, non-alpine region',
#            'electricity production, hydro, reservoir, tropical region',
#            'electricity production, hydro, run-of-river'},
#  'Hydro, run-of-river': {'electricity production, hydro, run-of-river'},
#  'Nuclear': {'electricity production, nuclear, boiling water reactor',
#              'electricity production, nuclear, pressure water reactor',
#              'electricity production, nuclear, pressure water reactor, heavy '
#              'water moderated'},
#  'Oil CC': {'electricity production, oil'},
#  'Oil CHP': {'heat and power co-generation, oil'},
#  'Oil ST': {'electricity production, oil'},
#  'Solar CSP': {'electricity production, solar thermal parabolic trough, 50 MW',
#                'electricity production, solar tower power plant, 20 MW'},
#  'Solar PV Centralized': {'electricity production, photovoltaic, commercial'},
#  'Solar PV Residential': {'electricity production, photovoltaic, residential'},
#  'Wave': {'electricity production, wave energy converter'},
#  'Wind Offshore': {'electricity production, wind, 1-3MW turbine, offshore'},
#  'Wind Onshore': {'electricity production, wind, 1-3MW turbine, onshore',
#                   'electricity production, wind, <1MW turbine, onshore',
#                   'electricity production, wind, >3MW turbine, onshore'}}
# Coal CHP ['heat and power co-generation, hard coal', 'heat and power co-generation, lignite']
# Gas CHP ['heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical']
# Solar PV Centralized ['electricity production, photovoltaic, commercial']
# Wave ['electricity production, wave energy converter']
# Coal USC CCS ['electricity production, at hard coal-fired power plant, ultra-super critical, oxy, pipeline 200km, storage 1000m']
# Geothermal ['electricity production, deep geothermal', 'electricity production, deep geothermal']
# Nuclear ['electricity production, nuclear, pressure water reactor']
# Coal SC ['electricity production, hard coal, supercritical']
# Gas CC CCS ['electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m']
# Wind Onshore ['electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore']
# Biomass CHP (existing) ['heat and power co-generation, existing, wood chips']
# Biomass IGCC ['electricity production, at biomass-fired IGCC power plant']
# Oil ST ['electricity production, oil', 'electricity production, oil']
# Hydro, run-of-river ['electricity production, hydro, run-of-river']
# Gas CC ['electricity production, natural gas, combined cycle power plant']
# Coal CF 50-50 ['electricity production, at co-firing wood and coal power plant, 50-50']
# Coal IGCC ['electricity production, at hard coal-fired IGCC power plant', 'electricity production, at lignite-fired IGCC power plant']
# Biomass ST ['electricity production, at wood burning power plant']
# Oil CC ['electricity production, oil', 'electricity production, oil']
# Oil CHP ['heat and power co-generation, oil']
# Gas OC ['electricity production, natural gas, conventional power plant']
# Biomass IGCC CCS ['electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biomass ST CCS ['electricity production, at wood burning power plant, post, pipeline 200km, storage 1000m']
# Solar CSP ['electricity production, solar tower power plant, 20 MW', 'electricity production, solar thermal parabolic trough, 50 MW']
# Biomass CHP ['heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW', 'heat and power co-generation, wood chips, 6667 kW']
# Coal CF 80-20 ['electricity production, at co-firing wood and coal power plant, 80-20']
# Wind Offshore ['electricity production, wind, 1-3MW turbine, offshore']
# Coal IGCC CCS ['electricity production, at hard coal-fired IGCC power plant, pre, pipeline 200km, storage 1000m', 'electricity production, at lignite-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biogas CHP ['heat and power co-generation, biogas, gas engine']
# Coal PC ['electricity production, hard coal, conventional', 'electricity production, hard coal']
# Coal USC ['electricity production, hard coal, ultra-supercritical']
# Gas GT ['electricity production, natural gas, gas turbine, conventional power plant']
# Hydro ['electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river']
# Biomass MSW ['treatment of municipal solid waste, incineration']
# 0 AFR
# {'Biogas CHP': 1.785418236531283e-10,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 6.506033880749184e-10,
#  'Biomass IGCC CCS': 0.0,
#  'Biomass MSW': 1.2018898892170346e-10,
#  'Biomass ST': 5.922448342611431e-10,
#  'Biomass ST CCS': 0.0,
#  'Coal CF 50-50': 2.1982633988720107e-09,
#  'Coal CF 80-20': 4.281713763059073e-09,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 3.6880286988740167e-09,
#  'Coal IGCC CCS': 8.006019035873249e-12,
#  'Coal PC': 0.20992130909210077,
#  'Coal SC': 0.36887017191487587,
#  'Coal USC': 8.955430935764757e-09,
#  'Coal USC CCS': 0.0,
#  'Gas CC': 0.13924650960858115,
#  'Gas CC CCS': 0.0,
#  'Gas CHP': 0.0,
#  'Gas GT': 1.7371526994658382e-09,
#  'Gas OC': 1.444997954624938e-09,
#  'Geothermal': 0.000885749010277124,
#  'Hydro': 0.1873504913313879,
#  'Hydro, run-of-river': 1.4351604295616376e-09,
#  'Nuclear': 0.01520460536663416,
#  'Oil CC': 5.837543261689904e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 9.195065664225062e-11,
#  'Solar CSP': 0.004675996899968194,
#  'Solar PV Centralized': 0.03146720702365043,
#  'Solar PV Residential': 3.1785719352872353e-09,
#  'Wave': 0.0,
#  'Wind Offshore': 0.01347280028202353,
#  'Wind Onshore': 0.028905130333897064}
# 20 AFR
# {'Biogas CHP': 0.0021334638031951098,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 3.8119127167255157e-10,
#  'Biomass IGCC CCS': 0.01524986028094499,
#  'Biomass MSW': 6.798097898102257e-11,
#  'Biomass ST': 3.5075050417472524e-10,
#  'Biomass ST CCS': 0.014085999250168138,
#  'Coal CF 50-50': 0.011631236715357656,
#  'Coal CF 80-20': 2.1189692860441565e-09,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 1.8765239116487094e-09,
#  'Coal IGCC CCS': 8.006019035873246e-12,
#  'Coal PC': 0.07437010119170855,
#  'Coal SC': 0.14894882743057955,
#  'Coal USC': 4.323833734588254e-09,
#  'Coal USC CCS': 0.02002385035771567,
#  'Gas CC': 0.056099856245741576,
#  'Gas CC CCS': 1.3332264418000546e-11,
#  'Gas CHP': 0.0,
#  'Gas GT': 9.288688736193991e-10,
#  'Gas OC': 8.50242256675035e-10,
#  'Geothermal': 0.013495303485403,
#  'Hydro': 0.37490321825668893,
#  'Hydro, run-of-river': 0.05003899151105333,
#  'Nuclear': 0.032752685246821206,
#  'Oil CC': 4.1520142100198305e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 3.910356353600111e-11,
#  'Solar CSP': 0.02941731295994035,
#  'Solar PV Centralized': 0.08462393179955204,
#  'Solar PV Residential': 0.04227706968460637,
#  'Wave': 0.00045773232123689074,
#  'Wind Offshore': 0.012573170891104818,
#  'Wind Onshore': 0.016917377204482883}
# 40 AFR
# {'Biogas CHP': 0.003180627894809426,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 1.9696388269962824e-10,
#  'Biomass IGCC CCS': 0.025723140153781007,
#  'Biomass MSW': 7.04093924852654e-11,
#  'Biomass ST': 1.8154743673318694e-10,
#  'Biomass ST CCS': 0.01764669663125324,
#  'Coal CF 50-50': 0.0062725998839363055,
#  'Coal CF 80-20': 1.0901903694721131e-09,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 9.711881791791448e-10,
#  'Coal IGCC CCS': 9.1739844327255e-12,
#  'Coal PC': 0.03809200304941169,
#  'Coal SC': 0.0771717777925473,
#  'Coal USC': 2.235311452592793e-09,
#  'Coal USC CCS': 0.010919249226421238,
#  'Gas CC': 0.028782381011556283,
#  'Gas CC CCS': 0.0007826544749002321,
#  'Gas CHP': 0.0,
#  'Gas GT': 4.7576210600018e-10,
#  'Gas OC': 4.354899363457497e-10,
#  'Geothermal': 0.025312146404464303,
#  'Hydro': 0.31757499515768384,
#  'Hydro, run-of-river': 0.04708917061088056,
#  'Nuclear': 0.04262692944058687,
#  'Oil CC': 2.2635468659210535e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 2.002865449404935e-11,
#  'Solar CSP': 0.07182523926677667,
#  'Solar PV Centralized': 0.16778856223839317,
#  'Solar PV Residential': 0.10055530791391602,
#  'Wave': 0.0004719779778495356,
#  'Wind Offshore': 0.009359836577674726,
#  'Wind Onshore': 0.00882469838640635}
# 60 AFR
# {'Biogas CHP': 0.0021680574589466924,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 1.3238556050302881e-10,
#  'Biomass IGCC CCS': 0.01910401694111124,
#  'Biomass MSW': 8.816350644327906e-11,
#  'Biomass ST': 1.2202368698460105e-10,
#  'Biomass ST CCS': 0.034866342184395965,
#  'Coal CF 50-50': 0.0042160097580555495,
#  'Coal CF 80-20': 7.327509040714203e-10,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 6.52765825349917e-10,
#  'Coal IGCC CCS': 7.724983480011998e-12,
#  'Coal PC': 0.025602821721735728,
#  'Coal SC': 0.05186955556548261,
#  'Coal USC': 1.5024224517426967e-09,
#  'Coal USC CCS': 0.007381276686393718,
#  'Gas CC': 0.019345534778259142,
#  'Gas CC CCS': 0.0005260464637879072,
#  'Gas CHP': 0.0,
#  'Gas GT': 3.197745302624161e-10,
#  'Gas OC': 2.927063506586186e-10,
#  'Geothermal': 0.024501200173804447,
#  'Hydro': 0.2600377572178147,
#  'Hydro, run-of-river': 0.03990169955974713,
#  'Nuclear': 0.03642647425835982,
#  'Oil CC': 1.5214003525043147e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 1.3461882528787267e-11,
#  'Solar CSP': 0.05609555187527471,
#  'Solar PV Centralized': 0.3195512913457993,
#  'Solar PV Residential': 0.08456022300773865,
#  'Wave': 0.0003445689517607665,
#  'Wind Offshore': 0.007570208432330757,
#  'Wind Onshore': 0.005931359607500896}
# Coal CHP ['heat and power co-generation, lignite']
# Gas CHP ['heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical']
# Solar PV Centralized ['electricity production, photovoltaic, commercial', 'electricity production, photovoltaic, commercial']
# Wave ['electricity production, wave energy converter']
# Coal USC CCS ['electricity production, at hard coal-fired power plant, ultra-super critical, oxy, pipeline 200km, storage 1000m']
# Geothermal ['electricity production, deep geothermal']
# Nuclear ['electricity production, nuclear, pressure water reactor, heavy water moderated', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, boiling water reactor']
# Coal SC ['electricity production, hard coal, supercritical']
# Gas CC CCS ['electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m']
# Wind Onshore ['electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore']
# Biomass CHP (existing) ['heat and power co-generation, existing, wood chips']
# Biomass IGCC ['electricity production, at biomass-fired IGCC power plant']
# Oil ST ['electricity production, oil']
# Hydro, run-of-river ['electricity production, hydro, run-of-river']
# Gas CC ['electricity production, natural gas, combined cycle power plant']
# Coal CF 50-50 ['electricity production, at co-firing wood and coal power plant, 50-50']
# Coal IGCC ['electricity production, at hard coal-fired IGCC power plant', 'electricity production, at lignite-fired IGCC power plant']
# Biomass ST ['electricity production, at wood burning power plant']
# Oil CC ['electricity production, oil']
# Oil CHP ['heat and power co-generation, oil']
# Gas OC ['electricity production, natural gas, conventional power plant']
# Biomass IGCC CCS ['electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biomass ST CCS ['electricity production, at wood burning power plant, post, pipeline 200km, storage 1000m']
# Solar CSP ['electricity production, solar tower power plant, 20 MW']
# Biomass CHP ['heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014']
# Coal CF 80-20 ['electricity production, at co-firing wood and coal power plant, 80-20']
# Wind Offshore ['electricity production, wind, 1-3MW turbine, offshore']
# Coal IGCC CCS ['electricity production, at hard coal-fired IGCC power plant, pre, pipeline 200km, storage 1000m', 'electricity production, at lignite-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biogas CHP ['heat and power co-generation, biogas, gas engine']
# Coal PC ['electricity production, lignite', 'electricity production, hard coal']
# Coal USC ['electricity production, hard coal, ultra-supercritical']
# Gas GT ['electricity production, natural gas, gas turbine, conventional power plant']
# Hydro ['electricity production, hydro, run-of-river']
# Biomass MSW ['treatment of municipal solid waste, incineration']
# 0 AUS
# {'Biogas CHP': 4.267591794589142e-10,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 8.331868329082819e-10,
#  'Biomass IGCC': 2.1068900189327443e-09,
#  'Biomass IGCC CCS': 0.0,
#  'Biomass MSW': 2.60995440304938e-10,
#  'Biomass ST': 1.89040867309435e-09,
#  'Biomass ST CCS': 0.0,
#  'Coal CF 50-50': 2.905734208322682e-09,
#  'Coal CF 80-20': 5.842065366683052e-09,
#  'Coal CHP': 0.011848954410710608,
#  'Coal IGCC': 4.548938928002395e-09,
#  'Coal IGCC CCS': 0.0,
#  'Coal PC': 0.35732528513939976,
#  'Coal SC': 0.17044505603017363,
#  'Coal USC': 1.0398450276401167e-08,
#  'Coal USC CCS': 0.0,
#  'Gas CC': 0.12054929195163247,
#  'Gas CC CCS': 0.0,
#  'Gas CHP': 1.6702845315083026e-08,
#  'Gas GT': 4.06246423651871e-09,
#  'Gas OC': 0.034114403910019006,
#  'Geothermal': 0.005842384708476161,
#  'Hydro': 0.1491967271286942,
#  'Hydro, run-of-river': 3.3181611892182496e-09,
#  'Nuclear': 0.0,
#  'Oil CC': 1.3358459066956404e-09,
#  'Oil CHP': 0.0,
#  'Oil ST': 2.903225327224869e-10,
#  'Solar CSP': 3.591035609435406e-05,
#  'Solar PV Centralized': 0.05844255700190775,
#  'Solar PV Residential': 7.238964867363708e-09,
#  'Wave': 2.19989629744883e-10,
#  'Wind Offshore': 0.028467998561982205,
#  'Wind Onshore': 0.06373136841888735}
# 20 AUS
# {'Biogas CHP': 0.030422163867782594,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 8.062018437190908e-05,
#  'Biomass IGCC': 1.1008567373003158e-09,
#  'Biomass IGCC CCS': 0.04107232948115975,
#  'Biomass MSW': 1.4173715765072567e-10,
#  'Biomass ST': 1.016647977888491e-09,
#  'Biomass ST CCS': 1.0035566783028035e-09,
#  'Coal CF 50-50': 0.009292950175898916,
#  'Coal CF 80-20': 3.923753105949656e-09,
#  'Coal CHP': 0.003656299088060853,
#  'Coal IGCC': 3.270795900931287e-09,
#  'Coal IGCC CCS': 0.0,
#  'Coal PC': 0.12120590840266277,
#  'Coal SC': 0.06563687239190981,
#  'Coal USC': 6.049540015858027e-09,
#  'Coal USC CCS': 0.02657488573390974,
#  'Gas CC': 0.04628419050911141,
#  'Gas CC CCS': 0.005422827979488462,
#  'Gas CHP': 0.0007715220586562832,
#  'Gas GT': 1.978185507837738e-09,
#  'Gas OC': 0.013744280310699342,
#  'Geothermal': 0.04041067596455958,
#  'Hydro': 0.13405004295514814,
#  'Hydro, run-of-river': 0.0026582630037271264,
#  'Nuclear': 0.011229943258564079,
#  'Oil CC': 9.686400575186825e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 1.1683918838183573e-10,
#  'Solar CSP': 0.060522654637479245,
#  'Solar PV Centralized': 0.1144653365978617,
#  'Solar PV Residential': 0.18375317417392042,
#  'Wave': 0.0071353035470038155,
#  'Wind Offshore': 0.03077409232786485,
#  'Wind Onshore': 0.05083564378407135}
# 40 AUS
# {'Biogas CHP': 0.022732287280764485,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 4.129326516609978e-05,
#  'Biomass IGCC': 5.682581140165166e-10,
#  'Biomass IGCC CCS': 0.03661653931700358,
#  'Biomass MSW': 2.355824833667125e-10,
#  'Biomass ST': 5.256917915117067e-10,
#  'Biomass ST CCS': 0.00583620226884653,
#  'Coal CF 50-50': 0.004949003851427615,
#  'Coal CF 80-20': 2.0210485448906697e-09,
#  'Coal CHP': 0.0018727385572994612,
#  'Coal IGCC': 1.6937464994397834e-09,
#  'Coal IGCC CCS': 0.0,
#  'Coal PC': 0.06208107503551019,
#  'Coal SC': 0.03394740079556023,
#  'Coal USC': 3.1289225442771253e-09,
#  'Coal USC CCS': 0.014394702683087441,
#  'Gas CC': 0.023758489407835825,
#  'Gas CC CCS': 0.004918194437376001,
#  'Gas CHP': 0.0003951698349215109,
#  'Gas GT': 1.0132169674290855e-09,
#  'Gas OC': 0.007039753329870395,
#  'Geothermal': 0.060651558473672686,
#  'Hydro': 0.0885555749316908,
#  'Hydro, run-of-river': 0.0022959007292170765,
#  'Nuclear': 0.024223704094293315,
#  'Oil CC': 5.29937873727606e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 5.984446234191586e-11,
#  'Solar CSP': 0.11228797079338329,
#  'Solar PV Centralized': 0.09169982525951097,
#  'Solar PV Residential': 0.3474484204619536,
#  'Wave': 0.005002161536837035,
#  'Wind Offshore': 0.02204564145210693,
#  'Wind Onshore': 0.027206382428702394}
# 60 AUS
# {'Biogas CHP': 0.015407947587911636,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 2.7754489701804767e-05,
#  'Biomass IGCC': 3.819439782733964e-10,
#  'Biomass IGCC CCS': 0.03618759432874323,
#  'Biomass MSW': 3.325384184975034e-10,
#  'Biomass ST': 3.5333382708163893e-10,
#  'Biomass ST CCS': 0.006401928417866173,
#  'Coal CF 50-50': 0.00332637963784479,
#  'Coal CF 80-20': 1.358409677713401e-09,
#  'Coal CHP': 0.001258725915561933,
#  'Coal IGCC': 1.1384197783119857e-09,
#  'Coal IGCC CCS': 0.0,
#  'Coal PC': 0.04172662420419538,
#  'Coal SC': 0.022817105452753596,
#  'Coal USC': 2.103046300251838e-09,
#  'Coal USC CCS': 0.009709257882256035,
#  'Gas CC': 0.015968820749528996,
#  'Gas CC CCS': 0.0033056716908268463,
#  'Gas CHP': 0.0002656059546193762,
#  'Gas GT': 6.810146830261067e-10,
#  'Gas OC': 0.004731637484011249,
#  'Geothermal': 0.07147043014643482,
#  'Hydro': 0.06822180703456981,
#  'Hydro, run-of-river': 0.0019783050527036813,
#  'Nuclear': 0.02353803144253617,
#  'Oil CC': 3.5618775119396474e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 4.0223327147845085e-11,
#  'Solar CSP': 0.08496805621629233,
#  'Solar PV Centralized': 0.16507133706404387,
#  'Solar PV Residential': 0.3846075163087421,
#  'Wave': 0.003362108801745306,
#  'Wind Offshore': 0.017361085448695527,
#  'Wind Onshore': 0.01828626194483456}
# Coal CHP ['heat and power co-generation, hard coal', 'heat and power co-generation, lignite']
# Gas CHP ['heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical', 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical']
# Solar PV Centralized ['electricity production, photovoltaic, commercial']
# Wave ['electricity production, wave energy converter']
# Coal USC CCS ['electricity production, at hard coal-fired power plant, ultra-super critical, oxy, pipeline 200km, storage 1000m']
# Geothermal ['electricity production, deep geothermal']
# Nuclear ['electricity production, nuclear, pressure water reactor, heavy water moderated', 'electricity production, nuclear, pressure water reactor, heavy water moderated', 'electricity production, nuclear, pressure water reactor, heavy water moderated']
# Coal SC ['electricity production, hard coal, supercritical']
# Gas CC CCS ['electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m']
# Wind Onshore ['electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore']
# Biomass CHP (existing) ['heat and power co-generation, existing, wood chips']
# Biomass IGCC ['electricity production, at biomass-fired IGCC power plant']
# Oil ST ['electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil']
# Hydro, run-of-river ['electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river']
# Gas CC ['electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant']
# Coal CF 50-50 ['electricity production, at co-firing wood and coal power plant, 50-50']
# Coal IGCC ['electricity production, at hard coal-fired IGCC power plant', 'electricity production, at lignite-fired IGCC power plant']
# Biomass ST ['electricity production, at wood burning power plant']
# Oil CC ['electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil']
# Oil CHP ['heat and power co-generation, oil']
# Gas OC ['electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant']
# Biomass IGCC CCS ['electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biomass ST CCS ['electricity production, at wood burning power plant, post, pipeline 200km, storage 1000m']
# Solar CSP ['electricity production, solar tower power plant, 20 MW', 'electricity production, solar thermal parabolic trough, 50 MW']
# Biomass CHP ['heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014']
# Coal CF 80-20 ['electricity production, at co-firing wood and coal power plant, 80-20']
# Wind Offshore ['electricity production, wind, 1-3MW turbine, offshore']
# Coal IGCC CCS ['electricity production, at hard coal-fired IGCC power plant, pre, pipeline 200km, storage 1000m', 'electricity production, at lignite-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biogas CHP ['heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine']
# Coal PC ['electricity production, hard coal', 'electricity production, hard coal', 'electricity production, lignite', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, lignite', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, lignite', 'electricity production, lignite', 'electricity production, lignite']
# Coal USC ['electricity production, hard coal, ultra-supercritical']
# Gas GT ['electricity production, natural gas, gas turbine, conventional power plant']
# Hydro ['electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river']
# Biomass MSW ['treatment of municipal solid waste, incineration']
# 0 CAN
# {'Biogas CHP': 1.8976677873226972e-10,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 1.0920203555206649e-09,
#  'Biomass IGCC CCS': 0.0,
#  'Biomass MSW': 9.364490884238096e-12,
#  'Biomass ST': 9.149967286497673e-10,
#  'Biomass ST CCS': 0.0,
#  'Coal CF 50-50': 1.7065749068882613e-09,
#  'Coal CF 80-20': 3.478523495259976e-09,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 1.6256582716746589e-09,
#  'Coal IGCC CCS': 2.4580206812329024e-11,
#  'Coal PC': 0.09578241611363131,
#  'Coal SC': 0.005265612492568097,
#  'Coal USC': 5.5749492036698544e-09,
#  'Coal USC CCS': 0.0,
#  'Gas CC': 0.07277786198239461,
#  'Gas CC CCS': 0.0,
#  'Gas CHP': 0.00950265791825986,
#  'Gas GT': 1.2994967760280446e-09,
#  'Gas OC': 2.6997753165003413e-09,
#  'Geothermal': 0.0,
#  'Hydro': 0.6054327624860465,
#  'Hydro, run-of-river': 7.53381576238152e-09,
#  'Nuclear': 0.14138993365424235,
#  'Oil CC': 6.159126869918767e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 1.8257415232513333e-10,
#  'Solar CSP': 9.22510422559851e-12,
#  'Solar PV Centralized': 0.00558381050948958,
#  'Solar PV Residential': 9.237171106991781e-10,
#  'Wave': 0.0,
#  'Wind Offshore': 0.014034450121553625,
#  'Wind Onshore': 0.050230466884032474}
# 20 CAN
# {'Biogas CHP': 1.1043580390199637e-10,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 5.842070857286105e-10,
#  'Biomass IGCC CCS': 0.03164092474240331,
#  'Biomass MSW': 9.364490884238093e-12,
#  'Biomass ST': 5.055897048350481e-10,
#  'Biomass ST CCS': 0.017819845251692154,
#  'Coal CF 50-50': 0.008750150953116462,
#  'Coal CF 80-20': 2.7124107064576278e-09,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 1.3661214712964714e-09,
#  'Coal IGCC CCS': 2.4580206812329024e-11,
#  'Coal PC': 0.029600015184159223,
#  'Coal SC': 0.023014710834064034,
#  'Coal USC': 3.519542138043952e-09,
#  'Coal USC CCS': 0.010500434845124463,
#  'Gas CC': 0.027317290567247986,
#  'Gas CC CCS': 3.01995368210632e-11,
#  'Gas CHP': 0.0028577796253914027,
#  'Gas GT': 6.291291542187587e-10,
#  'Gas OC': 1.1145632601339134e-08,
#  'Geothermal': 0.0,
#  'Hydro': 0.5807289901450507,
#  'Hydro, run-of-river': 0.02207991266128369,
#  'Nuclear': 0.1500032884411572,
#  'Oil CC': 4.992261604276552e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 9.533232662206294e-11,
#  'Solar CSP': 0.010824002984704071,
#  'Solar PV Centralized': 0.0077684152060576335,
#  'Solar PV Residential': 0.029032907492899964,
#  'Wave': 0.0008023035573476586,
#  'Wind Offshore': 0.016691000560578467,
#  'Wind Onshore': 0.030568005749875133}
# 40 CAN
# {'Biogas CHP': 2.5276032892598397e-10,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 3.039684148315423e-10,
#  'Biomass IGCC CCS': 0.036231068002271355,
#  'Biomass MSW': 1.3509723843972453e-10,
#  'Biomass ST': 2.637582094084346e-10,
#  'Biomass ST CCS': 0.018432505430944473,
#  'Coal CF 50-50': 0.0048158644354906015,
#  'Coal CF 80-20': 1.398705473216944e-09,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 7.145278870523095e-10,
#  'Coal IGCC CCS': 2.490773896277458e-11,
#  'Coal PC': 0.015160983387008383,
#  'Coal SC': 0.012009206866050892,
#  'Coal USC': 1.8306599107200198e-09,
#  'Coal USC CCS': 0.00584054567702317,
#  'Gas CC': 0.014027113388865052,
#  'Gas CC CCS': 7.934078552014806e-11,
#  'Gas CHP': 0.00146374078373706,
#  'Gas GT': 3.2223688386814467e-10,
#  'Gas OC': 5.708738649466385e-09,
#  'Geothermal': 0.0,
#  'Hydro': 0.45474529818477627,
#  'Hydro, run-of-river': 0.02385330316175372,
#  'Nuclear': 0.1560623644495913,
#  'Oil CC': 2.828886468216037e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 4.882875266008102e-11,
#  'Solar CSP': 0.01594215769115679,
#  'Solar PV Centralized': 0.15511138681350023,
#  'Solar PV Residential': 0.054109902958708246,
#  'Wave': 0.0009464243641934076,
#  'Wind Offshore': 0.015266082839120197,
#  'Wind Onshore': 0.015982040220962817}
# 60 CAN
# {'Biogas CHP': 4.5176150549199057e-10,
#  'Biomass CHP': 0.0,
#  'Biomass CHP (existing)': 0.0,
#  'Biomass IGCC': 2.0430663947693825e-10,
#  'Biomass IGCC CCS': 0.05809784302013659,
#  'Biomass MSW': 2.7028530603575635e-10,
#  'Biomass ST': 1.7728010796304622e-10,
#  'Biomass ST CCS': 0.019922227168076404,
#  'Coal CF 50-50': 0.003236892489428109,
#  'Coal CF 80-20': 9.40113514785159e-10,
#  'Coal CHP': 0.0,
#  'Coal IGCC': 4.802564486745031e-10,
#  'Coal IGCC CCS': 2.3893715843041478e-11,
#  'Coal PC': 0.010190169161759733,
#  'Coal SC': 0.008071761991935846,
#  'Coal USC': 1.2304435465495214e-09,
#  'Coal USC CCS': 0.003960900268844972,
#  'Gas CC': 0.009428059818745362,
#  'Gas CC CCS': 8.331642405807924e-11,
#  'Gas CHP': 0.0009838257726757288,
#  'Gas GT': 2.1658544653432675e-10,
#  'Gas OC': 3.837021059477406e-09,
#  'Geothermal': 0.0,
#  'Hydro': 0.3989752372767688,
#  'Hydro, run-of-river': 0.02291262657367573,
#  'Nuclear': 0.1350262259420138,
#  'Oil CC': 1.9013827081452053e-10,
#  'Oil CHP': 0.0,
#  'Oil ST': 3.281932555841511e-11,
#  'Solar CSP': 0.011573974456570532,
#  'Solar PV Centralized': 0.20108256244583592,
#  'Solar PV Residential': 0.03824247507664195,
#  'Wave': 0.0007150472927813025,
#  'Wind Offshore': 0.01443117656008179,
#  'Wind Onshore': 0.06314898656546501}
# Coal CHP ['heat and power co-generation, hard coal']
# Gas CHP ['heat and power co-generation, natural gas, conventional power plant, 100MW electrical']
# Solar PV Centralized ['electricity production, photovoltaic, commercial']
# Wave ['electricity production, wave energy converter']
# Coal USC CCS ['electricity production, at hard coal-fired power plant, ultra-super critical, oxy, pipeline 200km, storage 1000m']
# Geothermal ['electricity production, deep geothermal', 'electricity production, deep geothermal']
# Nuclear ['electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor, heavy water moderated', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, boiling water reactor', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor', 'electricity production, nuclear, pressure water reactor']
# Coal SC ['electricity production, hard coal, supercritical']
# Gas CC CCS ['electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m']
# Wind Onshore ['electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, >3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, 1-3MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', 'electricity production, wind, <1MW turbine, onshore', ' ...
# Biomass CHP (existing) ['heat and power co-generation, existing, wood chips']
# Biomass IGCC ['electricity production, at biomass-fired IGCC power plant']
# Oil ST ['electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil']
# Hydro, run-of-river ['electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river']
# Gas CC ['electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant']
# Coal CF 50-50 ['electricity production, at co-firing wood and coal power plant, 50-50']
# Coal IGCC ['electricity production, at hard coal-fired IGCC power plant', 'electricity production, at lignite-fired IGCC power plant']
# Biomass ST ['electricity production, at wood burning power plant']
# Oil CC ['electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil']
# ...
# Hydro, run-of-river ['electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river']
# Gas CC ['electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant', 'electricity production, natural gas, combined cycle power plant']
# Coal CF 50-50 ['electricity production, at co-firing wood and coal power plant, 50-50']
# Coal IGCC ['electricity production, at hard coal-fired IGCC power plant', 'electricity production, at lignite-fired IGCC power plant']
# Biomass ST ['electricity production, at wood burning power plant']
# Oil CC ['electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil', 'electricity production, oil']
# Oil CHP ['heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil', 'heat and power co-generation, oil']
# Gas OC ['electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant', 'electricity production, natural gas, conventional power plant']
# Biomass IGCC CCS ['electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biomass ST CCS ['electricity production, at wood burning power plant, post, pipeline 200km, storage 1000m']
# Solar CSP ['electricity production, solar thermal parabolic trough, 50 MW', 'electricity production, solar tower power plant, 20 MW']
# Biomass CHP ['heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 2000 kW', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 2000 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014']
# Coal CF 80-20 ['electricity production, at co-firing wood and coal power plant, 80-20']
# Wind Offshore ['electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore', 'electricity production, wind, 1-3MW turbine, offshore']
# Coal IGCC CCS ['electricity production, at hard coal-fired IGCC power plant, pre, pipeline 200km, storage 1000m', 'electricity production, at lignite-fired IGCC power plant, pre, pipeline 200km, storage 1000m']
# Biogas CHP ['heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine, renewable energy products', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine', 'heat and power co-generation, biogas, gas engine']
# Coal PC ['electricity production, hard coal', 'electricity production, lignite', 'electricity production, hard coal', 'electricity production, lignite', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, lignite', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, hard coal', 'electricity production, lignite']
# Coal USC ['electricity production, hard coal, ultra-supercritical']
# Gas GT ['electricity production, natural gas, gas turbine, conventional power plant']
# Hydro ['electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, non-alpine region', 'electricity production, hydro, run-of-river', 'electricity production, hydro, run-of-river', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, reservoir, alpine region', 'electricity production, hydro, run-of-river']
# Biomass MSW ['treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration', 'treatment of municipal solid waste, incineration']
# 0 WEU
# {'Biogas CHP': 1.3042429458347874e-10,
#  'Biomass CHP': 1.6743929110922612e-09,
#  'Biomass CHP (existing)': 0.0023063289738874887,
#  'Biomass IGCC': 0.04702146140686405,
#  'Biomass IGCC CCS': 0.0,
#  'Biomass MSW': 3.2869608858801975e-11,
#  'Biomass ST': 0.001459486973699367,
#  'Biomass ST CCS': 0.0,
#  'Coal CF 50-50': 2.4303363446046917e-10,
#  'Coal CF 80-20': 4.4522887439171363e-10,
#  'Coal CHP': 0.014313865143450387,
#  'Coal IGCC': 3.5332320424993545e-10,
#  'Coal IGCC CCS': 6.1326241615983075e-12,
#  'Coal PC': 0.1178054804162506,
#  'Coal SC': 0.09203148059472784,
#  'Coal USC': 8.710828021823151e-10,
#  'Coal USC CCS': 0.0,
#  'Gas CC': 0.08281638310744538,
#  'Gas CC CCS': 0.0,
#  'Gas CHP': 0.036538615361645356,
#  'Gas GT': 3.08808734782355e-10,
#  'Gas OC': 2.2049538028756643e-09,
#  'Geothermal': 0.0013538611018036153,
#  'Hydro': 0.19480420160684592,
#  'Hydro, run-of-river': 0.003632719580844509,
#  'Nuclear': 0.2392139945822204,
#  'Oil CC': 1.5889591130437906e-10,
#  'Oil CHP': 0.003790164395244267,
#  'Oil ST': 3.825607539322095e-11,
#  'Solar CSP': 0.0013228115838900812,
#  'Solar PV Centralized': 0.04540660803582936,
#  'Solar PV Residential': 6.058905420446791e-10,
#  'Wave': 0.00012241125338292383,
#  'Wind Offshore': 0.0034972827160968376,
#  'Wind Onshore': 0.11256283609871137}
# 20 WEU
# {'Biogas CHP': 7.549445129612557e-11,
#  'Biomass CHP': 0.0013752074118667233,
#  'Biomass CHP (existing)': 0.0003294756277934746,
#  'Biomass IGCC': 0.008649891098944222,
#  'Biomass IGCC CCS': 0.018140406206394698,
#  'Biomass MSW': 2.834926945492318e-11,
#  'Biomass ST': 0.001228218914466381,
#  'Biomass ST CCS': 0.026361463680927136,
#  'Coal CF 50-50': 0.005230979245175555,
#  'Coal CF 80-20': 5.679382025631019e-10,
#  'Coal CHP': 0.004947345445793826,
#  'Coal IGCC': 5.825763632574202e-10,
#  'Coal IGCC CCS': 6.132624161598311e-12,
#  'Coal PC': 0.05263845961487941,
#  'Coal SC': 0.043673404548225755,
#  'Coal USC': 1.1036219266454078e-09,
#  'Coal USC CCS': 0.01100194843867527,
#  'Gas CC': 0.030772299033540913,
#  'Gas CC CCS': 5.762630305967185e-12,
#  'Gas CHP': 0.012628954547178333,
#  'Gas GT': 1.449876205689053e-10,
#  'Gas OC': 5.888269733313457e-10,
#  'Geothermal': 0.008468701795871563,
#  'Hydro': 0.2278210294305729,
#  'Hydro, run-of-river': 0.005450097925144734,
#  'Nuclear': 0.24547285685370326,
#  'Oil CC': 1.3482577321831346e-10,
#  'Oil CHP': 0.0017579694526901884,
#  'Oil ST': 1.6167045349114887e-11,
#  'Solar CSP': 0.006994901666506887,
#  'Solar PV Centralized': 0.1640685108541145,
#  'Solar PV Residential': 0.030520830965519368,
#  'Wave': 0.0003088695217801152,
#  'Wind Offshore': 0.005246904643273096,
#  'Wind Onshore': 0.0869112698293326}
# 40 WEU
# {'Biogas CHP': 1.47449351192304e-10,
#  'Biomass CHP': 0.0007043745280292973,
#  'Biomass CHP (existing)': 0.00016875580935763333,
#  'Biomass IGCC': 0.0044304320277815746,
#  'Biomass IGCC CCS': 0.009291427808011463,
#  'Biomass MSW': 8.046516357812138e-11,
#  'Biomass ST': 0.0006290877382515409,
#  'Biomass ST CCS': 0.021724492915662325,
#  'Coal CF 50-50': 0.0028823870139881207,
#  'Coal CF 80-20': 2.9740539274407526e-10,
#  'Coal CHP': 0.002534006203943179,
#  'Coal IGCC': 3.2106331333689693e-10,
#  'Coal IGCC CCS': 7.0753629327184424e-12,
#  'Coal PC': 0.026961162241767502,
#  'Coal SC': 0.02255282491510131,
#  'Coal USC': 5.797595885792108e-10,
#  'Coal USC CCS': 0.006297110110115926,
#  'Gas CC': 0.015761421463133838,
#  'Gas CC CCS': 2.3705153673646244e-11,
#  'Gas CHP': 0.006468488914408415,
#  'Gas GT': 7.42619519987076e-11,
#  'Gas OC': 3.015943034136161e-10,
#  'Geothermal': 0.01882848026730982,
#  'Hydro': 0.18052271735477715,
#  'Hydro, run-of-river': 0.00519412223137319,
#  'Nuclear': 0.2487773892449653,
#  'Oil CC': 7.786184807613862e-11,
#  'Oil CHP': 0.0009004233782071696,
#  'Oil ST': 8.280681764180795e-12,
#  'Solar CSP': 0.006465496436751604,
#  'Solar PV Centralized': 0.22609761347951046,
#  'Solar PV Residential': 0.054313917949055004,
#  'Wave': 0.00026423169911888174,
#  'Wind Offshore': 0.004940813163668792,
#  'Wind Onshore': 0.13328882119070043}
# 60 WEU
# {'Biogas CHP': 1.7233853625371346e-10,
#  'Biomass CHP': 0.0004734320598229703,
#  'Biomass CHP (existing)': 0.00011342603579775355,
#  'Biomass IGCC': 0.0029778313629351565,
#  'Biomass IGCC CCS': 0.015115426621115004,
#  'Biomass MSW': 1.0393883023294249e-10,
#  'Biomass ST': 0.00042282946341497013,
#  'Biomass ST CCS': 0.02111716612910105,
#  'Coal CF 50-50': 0.0019373420913690648,
#  'Coal CF 80-20': 1.9989542790995224e-10,
#  'Coal CHP': 0.0017031844977323006,
#  'Coal IGCC': 2.1595547407157233e-10,
#  'Coal IGCC CCS': 6.941546877893245e-12,
#  'Coal PC': 0.01812143691659783,
#  'Coal SC': 0.01515845609047793,
#  'Coal USC': 3.896744775696335e-10,
#  'Coal USC CCS': 0.004268391891792523,
#  'Gas CC': 0.010593742294893235,
#  'Gas CC CCS': 2.6096466833155753e-11,
#  'Gas CHP': 0.0043476728768974595,
#  'Gas GT': 4.9913771015524776e-11,
#  'Gas OC': 2.0271092524521736e-10,
#  'Geothermal': 0.02167882219109639,
#  'Hydro': 0.1575096329787838,
#  'Hydro, run-of-river': 0.0052324995640190145,
#  'Nuclear': 0.2115119732609933,
#  'Oil CC': 5.2333373297076777e-11,
#  'Oil CHP': 0.000605202598467114,
#  'Oil ST': 5.565704136580534e-12,
#  'Solar CSP': 0.004345661593247835,
#  'Solar PV Centralized': 0.2626815266626892,
#  'Solar PV Residential': 0.04326209325303199,
#  'Wave': 0.00018277171201428063,
#  'Wind Offshore': 0.004610437655779912,
#  'Wind Onshore': 0.19202903877665628}
# Done!

# %%
ndb.write_db_to_brightway("test_tiam")
# Out:
# Write new database(s) to Brightway2.
# Database test_tiam already exists: it will be overwritten.
# Writing activities to SQLite3 database:
# Vacuuming database
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:23
# Title: Writing activities to SQLite3 database:
#   Started: 10/05/2023 17:43:33
#   Finished: 10/05/2023 17:43:56
#   Total time elapsed: 00:00:23
#   CPU %: 96.20
#   Memory %: 13.77
# Created database: test_tiam
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.

# %%
ndb.generate_change_report()
# Out:
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.

# %%
import wurst.searching as ws
name = "heat and power co-generation, wood chips"
ref_prod = "electricity, high voltage"
for d in ws.get_many(
        ndb.database,
        ws.equals("name", name),
        ws.contains("reference product", ref_prod),
):
    print(d["location"])

# %%
ndb.scenarios[0]["iam data"].production_volumes.region.values
# Out:
# array(['AFR', 'AUS', 'CAN', 'CHI', 'CSA', 'EEU', 'FSU', 'IND', 'JPN',
#        'MEA', 'MEX', 'ODA', 'SKO', 'UK', 'USA', 'WEU', 'World'],
#       dtype=object)

# %%
ndb.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway2.
# Database ecoinvent_cutoff_3.9_remind_SSP1-PkBudg500_2030 already exists: it will be overwritten.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:56
# Title: Writing activities to SQLite3 database:
#   Started: 08/08/2023 13:46:33
#   Finished: 08/08/2023 13:47:30
#   Total time elapsed: 00:00:56
#   CPU %: 99.20
#   Memory %: 23.54
# Created database: ecoinvent_cutoff_3.9_remind_SSP1-PkBudg500_2030
# Writing activities to SQLite3 database:
# 0% [###########                   ] 100% | ETA: 00:00:35

# %%
for ds in ndb.scenarios[0]["database"]:
    for e in ds["exchanges"]:
        if e["name"] == "carbon dioxide, captured from atmosphere, with a sorbent-based direct air capture system, 100ktCO2":
            print(ds["name"], ds["location"])
# Out:
# methane, from electrochemical methanation, with carbon from atmospheric carbon dioxide capture RER
# methane, from biological methanation, with carbon from atmospheric carbon dioxide capture RER

# %%
ndb.generate_change_report()
# Out:
# Generate change report.
# Report saved under /Users/romain/Github/premise/dev.

# %%
ndb.scenarios[0]["iam data"].gas_markets.sel(region="World")
# Out:
# <xarray.DataArray 'value' (variables: 2, year: 19)>
# array([[9.91877907e-01, 9.90871332e-01, 9.91196756e-01, 9.91188649e-01,
#         9.90118025e-01, 9.83021566e-01, 9.75568480e-01, 9.63609588e-01,
#         9.43883991e-01, 9.28584201e-01, 9.42510199e-01, 9.59305111e-01,
#         9.82257021e-01, 9.97215137e-01, 9.99995102e-01, 9.99995157e-01,
#         9.99995735e-01, 9.99999014e-01, 9.99972882e-01],
#        [8.12209329e-03, 9.12866826e-03, 8.80324396e-03, 8.81135120e-03,
#         9.88197487e-03, 1.69784344e-02, 2.44315195e-02, 3.63904117e-02,
#         5.61160093e-02, 7.14157994e-02, 5.74898011e-02, 4.06948892e-02,
#         1.77429794e-02, 2.78486319e-03, 4.89775356e-06, 4.84292554e-06,
#         4.26532184e-06, 9.86388757e-07, 2.71178968e-05]])
# Coordinates:
#     region     <U5 'World'
#   * variables  (variables) <U11 'natural gas' 'biomethane'
#   * year       (year) int64 2005 2010 2015 2020 2025 ... 2100 2110 2130 2150

# %%
ndb.scenarios[0].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 ndb.cache
#
# AttributeError: 'NewDatabase' object has no attribute 'cache'

# %%
for ds in ndb.scenarios[0]["database"]:
    for e in ds["exchanges"]:
        if e["name"] == "market for platinum" and e["product"] == "platinum":
            print(ds["name"], ds["location"], e["name"], e["location"])
# Out:
# petrol production, unleaded, petroleum refinery operation IN market for platinum GLO
# pitch production, petroleum refinery operation RoW market for platinum World
# reformate production, petroleum refinery operation RoW market for platinum World
# sulfur production, petroleum refinery operation PE market for platinum GLO
# petroleum coke production, petroleum refinery operation RoW market for platinum World
# heavy fuel oil production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation IN market for platinum GLO
# base oil production, petroleum refinery operation BR market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation CO market for platinum GLO
# white spirit production, petroleum refinery operation RoW market for platinum World
# white spirit production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# internal combustion engine production, passenger car GLO market for platinum World
# light fuel oil production, petroleum refinery operation IN market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation PE market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation RoW market for platinum World
# reformate production, petroleum refinery operation ZA market for platinum GLO
# catalytic converter production, oxidation, 20 litre RoW market for platinum World
# sulfur production, petroleum refinery operation IN market for platinum GLO
# electric parts production, heat and power co-generation unit, 160kW electrical RER market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation PE market for platinum GLO
# petroleum slack wax production, petroleum refinery operation BR market for platinum GLO
# fuel cell production, polymer electrolyte membrane, 2kW electrical, future CH market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation BR market for platinum GLO
# motor scooter production RoW market for platinum World
# naphtha production, petroleum refinery operation CO market for platinum GLO
# fuel cell production, polymer electrolyte membrane, 2kW electrical, future RoW market for platinum World
# refinery gas production, petroleum refinery operation IN market for platinum GLO
# petroleum slack wax production, petroleum refinery operation IN market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation CO market for platinum GLO
# kerosene production, petroleum refinery operation CO market for platinum GLO
# pitch production, petroleum refinery operation IN market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation IN market for platinum GLO
# reformate production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# motor scooter production RER market for platinum GLO
# light fuel oil production, petroleum refinery operation PE market for platinum GLO
# heavy fuel oil production, petroleum refinery operation RoW market for platinum World
# white spirit production, petroleum refinery operation ZA market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# reformate production, petroleum refinery operation PE market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# light fuel oil production, petroleum refinery operation RoW market for platinum World
# C3 hydrocarbon production, mixture, petroleum refinery operation BR market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# nuclear power plant construction, pressure water reactor 650MW CA-QC market for platinum GLO
# heavy fuel oil production, petroleum refinery operation PE market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# petrol production, unleaded, petroleum refinery operation BR market for platinum GLO
# nuclear power plant construction, pressure water reactor 650MW RoW market for platinum World
# ascorbic acid production RoW market for platinum World
# kerosene production, petroleum refinery operation IN market for platinum GLO
# ascorbic acid production RER market for platinum GLO
# reformate production, petroleum refinery operation CO market for platinum GLO
# kerosene production, petroleum refinery operation RoW market for platinum World
# catalytic converter production, oxidation, 20 litre RER market for platinum GLO
# naphtha production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation IN market for platinum GLO
# white spirit production, petroleum refinery operation IN market for platinum GLO
# diesel production, petroleum refinery operation BR market for platinum GLO
# base oil production, petroleum refinery operation CO market for platinum GLO
# petroleum coke production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation RoW market for platinum World
# sulfur production, petroleum refinery operation BR market for platinum GLO
# electric parts production, heat and power co-generation unit, 160kW electrical RoW market for platinum World
# sodium perchlorate production GLO market for platinum World
# hydrogen production, gaseous, petroleum refinery operation ZA market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation BR market for platinum GLO
# refinery gas production, petroleum refinery operation ZA market for platinum GLO
# pitch production, petroleum refinery operation CO market for platinum GLO
# refinery gas production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# catalytic converter production, three-way, 19.1l RoW market for platinum World
# maintenance, polymer electrolyte membrane fuel cell 2kW electrical CH market for platinum GLO
# electric parts production, mini CHP plant CH market for platinum GLO
# fuel cell production, stack polymer electrolyte membrane, 2kW electrical, future RoW market for platinum World
# petrol production, unleaded, petroleum refinery operation PE market for platinum GLO
# petroleum slack wax production, petroleum refinery operation ZA market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation ZA market for platinum GLO
# white spirit production, petroleum refinery operation BR market for platinum GLO
# light fuel oil production, petroleum refinery operation ZA market for platinum GLO
# white spirit production, petroleum refinery operation PE market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation CO market for platinum GLO
# light fuel oil production, petroleum refinery operation BR market for platinum GLO
# heavy fuel oil production, petroleum refinery operation IN market for platinum GLO
# fuel cell production, stack polymer electrolyte membrane, 2kW electrical, future CH market for platinum GLO
# sulfur production, petroleum refinery operation ZA market for platinum GLO
# white spirit production, petroleum refinery operation CO market for platinum GLO
# refinery gas production, petroleum refinery operation CO market for platinum GLO
# petroleum coke production, petroleum refinery operation ZA market for platinum GLO
# base oil production, petroleum refinery operation PE market for platinum GLO
# diesel production, petroleum refinery operation PE market for platinum GLO
# naphtha production, petroleum refinery operation IN market for platinum GLO
# heavy fuel oil production, petroleum refinery operation BR market for platinum GLO
# petroleum slack wax production, petroleum refinery operation CO market for platinum GLO
# maintenance, polymer electrolyte membrane fuel cell 2kW electrical RoW market for platinum World
# refinery gas production, petroleum refinery operation RoW market for platinum World
# pitch production, petroleum refinery operation ZA market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation IN market for platinum GLO
# pitch production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# pitch production, petroleum refinery operation PE market for platinum GLO
# power saw production, with catalytic converter GLO market for platinum World
# kerosene production, petroleum refinery operation ZA market for platinum GLO
# pitch production, petroleum refinery operation BR market for platinum GLO
# naphtha production, petroleum refinery operation ZA market for platinum GLO
# petroleum slack wax production, petroleum refinery operation RoW market for platinum World
# base oil production, petroleum refinery operation RoW market for platinum World
# liquefied petroleum gas production, petroleum refinery operation CO market for platinum GLO
# diesel production, petroleum refinery operation RoW market for platinum World
# C3 hydrocarbon production, mixture, petroleum refinery operation Europe without Switzerland market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# light fuel oil production, petroleum refinery operation CO market for platinum GLO
# base oil production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# base oil production, petroleum refinery operation IN market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation RoW market for platinum World
# petroleum slack wax production, petroleum refinery operation PE market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation PE market for platinum GLO
# light fuel oil production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation CO market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation BR market for platinum GLO
# heavy fuel oil production, petroleum refinery operation CO market for platinum GLO
# reformate production, petroleum refinery operation BR market for platinum GLO
# reformate production, petroleum refinery operation IN market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation IN market for platinum GLO
# control cabinet production, heat and power co-generation unit, 160kW electrical RER market for platinum GLO
# petroleum slack wax production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# control cabinet production, heat and power co-generation unit, 160kW electrical RoW market for platinum World
# C3 hydrocarbon production, mixture, petroleum refinery operation PE market for platinum GLO
# petroleum refinery operation CH market for platinum GLO
# sulfur production, petroleum refinery operation RoW market for platinum World
# diesel production, petroleum refinery operation ZA market for platinum GLO
# diesel production, petroleum refinery operation CO market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation ZA market for platinum GLO
# kerosene production, petroleum refinery operation BR market for platinum GLO
# refinery gas production, petroleum refinery operation PE market for platinum GLO
# platinum to generic market for metal catalyst for catalytic converter GLO market for platinum World
# petrol production, unleaded, petroleum refinery operation ZA market for platinum GLO
# naphtha production, petroleum refinery operation BR market for platinum GLO
# C3 hydrocarbon production, mixture, petroleum refinery operation RoW market for platinum World
# base oil production, petroleum refinery operation ZA market for platinum GLO
# hydrogen production, gaseous, petroleum refinery operation Europe without Switzerland market for platinum GLO
# diesel production, petroleum refinery operation IN market for platinum GLO
# electricity production, medium voltage, petroleum refinery operation Europe without Switzerland market for platinum GLO
# naphtha production, petroleum refinery operation PE market for platinum GLO
# catalytic converter production, three-way, 19.1l RER market for platinum GLO
# liquefied petroleum gas production, petroleum refinery operation ZA market for platinum GLO
# electric parts production, mini CHP plant RoW market for platinum World
# refinery gas production, petroleum refinery operation BR market for platinum GLO
# heavy fuel oil production, petroleum refinery operation ZA market for platinum GLO
# diesel production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# sulfur production, petroleum refinery operation CO market for platinum GLO
# diesel production, low-sulfur, petroleum refinery operation Europe without Switzerland market for platinum GLO
# naphtha production, petroleum refinery operation RoW market for platinum World
# kerosene production, petroleum refinery operation PE market for platinum GLO
# kerosene production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# petrol production, unleaded, petroleum refinery operation Europe without Switzerland market for platinum GLO
# petrol production, unleaded, petroleum refinery operation RoW market for platinum World
# diesel production, low-sulfur, petroleum refinery operation RoW market for platinum World
# petrol production, unleaded, petroleum refinery operation CO market for platinum GLO
# sulfur production, petroleum refinery operation Europe without Switzerland market for platinum GLO
# electrolyzer production, 1MWe, PEM, Stack RER market for platinum GLO
# hydrogenation of hydrogen RER market for platinum GLO
# dehydrogenation of hydrogen RER market for platinum GLO
# fuel cell stack production, 1 kWe, proton exchange membrane (PEM) GLO market for platinum World
# market for platinum World market for platinum World

# %%
import pprint
for ds in ndb.scenarios[0]["database"]:
    if ds["name"].lower() == "lithium carbonate, precipitated":
        print(ds["name"], ds["location"])

# %%
from premise.activity_maps import InventorySet
inv = InventorySet(ndb.database, "3.9")

# %%
inv.generate_metals_map()
# Out:
# {'Dysprosium': {'Dysprosium'},
#  'Neodymium': {'Neodymium, 4% in bastnasite, 0.4% in crude ore'},
#  'Nickel': {'Nickel',
#   'Nickel, 1.13% in sulfide, Ni 0.76% and Cu 0.76% in crude ore',
#   'Nickel, 1.98% in silicates, 1.04% in crude ore',
#   'Nickel, Ni 2.5E+0%, in mixed ore'},
#  'Manganese': {'Manganese',
#   'Manganese, 35.7% in sedimentary deposit, 14.2% in crude ore'},
#  'Yttrium': {'Yttrium'},
#  'Vanadium': {'Vanadium'},
#  'Cobalt': {'Cobalt', 'Cobalt, Co 5.0E-2%, in mixed ore'},
#  'Lithium': {'Lithium', 'Lithium, 0.15% in brine'},
#  'Sulfur': {'Sulfur'},
#  'Platinum': {'Platinum', 'Platinum, Pt 4.7E-7%, in mixed ore'},
#  'Cerium': {'Cerium', 'Cerium, 24% in bastnasite, 2.4% in crude ore'},
#  'Lanthanum': {'Lanthanum',
#   'Lanthanum, 7.2% in bastnasite, 0.72% in crude ore'},
#  'Zirconium': {'Zirconium', 'Zirconium, 50% in zircon, 0.39% in crude ore'},
#  'Gadolinium': {'Gadolinium',
#   'Gadolinium, 0.15% in bastnasite, 0.015% in crude ore'},
#  'Scandium': {'Scandium'},
#  'Strontium': {'Strontium'},
#  'Potassium': {'Potassium'},
#  'Iridium': {'Iridium'},
#  'Silver': {'Silver',
#   'Silver, 0.007% in sulfide, Ag 0.004%, Pb, Zn, Cd, In',
#   'Silver, 0.01% in crude ore',
#   'Silver, 3.2ppm in sulfide, Ag 1.2ppm, Cu and Te, in crude ore',
#   'Silver, Ag 1.5E-4%, Au 6.8E-4%, in ore',
#   'Silver, Ag 1.5E-5%, Au 5.4E-4%, in ore',
#   'Silver, Ag 1.8E-6%, in mixed ore',
#   'Silver, Ag 2.1E-4%, Au 2.1E-4%, in ore',
#   'Silver, Ag 4.2E-3%, Au 1.1E-4%, in ore',
#   'Silver, Ag 4.6E-5%, Au 1.3E-4%, in ore',
#   'Silver, Ag 5.4E-3%, in mixed ore',
#   'Silver, Ag 7.6E-5%, Au 9.7E-5%, in ore',
#   'Silver, Ag 9.7E-4%, in mixed ore'},
#  'Germanium': {'Germanium'},
#  'Indium': {'Indium', 'Indium, 0.005% in sulfide, In 0.003%, Pb, Zn, Ag, Cd'},
#  'Gallium': {'Gallium', 'Gallium, 0.014% in bauxite'},
#  'Selenium': {'Selenium'},
#  'Cadmium': {'Cadmium', 'Cadmium, 0.30% in sulfide, Cd 0.18%, Pb, Zn, Ag, In'},
#  'Tellurium': {'Tellurium',
#   'Tellurium, 0.5ppm in sulfide, Te 0.2ppm, Cu and Ag, in crude ore'}}

# %%
inv.generate_powerplant_map()
# Out:
# {'Biomass CHP': {'heat and power co-generation, wood chips, 2000 kW',
#   'heat and power co-generation, wood chips, 2000 kW, state-of-the-art 2014',
#   'heat and power co-generation, wood chips, 6667 kW',
#   'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014',
#   'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014, renewable energy products'},
#  'Biomass CHP CCS': {'electricity production, at co-generation power plant/wood, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/wood, post, pipeline 400km, storage 3000m'},
#  'Biomass ST': {'electricity production, at wood burning power plant 20 MW, truck 25km, no CCS'},
#  'Biomass IGCC CCS': {'electricity production, at BIGCC power plant, pre, pipeline 200km, storage 1000m',
#   'electricity production, at wood burning power plant 20 MW, truck 25km, post, pipeline 200km, storage 1000m'},
#  'Biomass IGCC': {'electricity production, at BIGCC power plant, no CCS'},
#  'Coal PC': {'electricity production, hard coal',
#   'electricity production, hard coal, at coal mine power plant',
#   'electricity production, hard coal, conventional',
#   'electricity production, hard coal, supercritical',
#   'electricity production, lignite'},
#  'Coal IGCC': {'electricity production, at power plant/hard coal, IGCC, no CCS',
#   'electricity production, at power plant/lignite, IGCC, no CCS'},
#  'Coal PC CCS': {'electricity production, at power plant/hard coal, post, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/lignite, post, pipeline 200km, storage 1000m'},
#  'Coal IGCC CCS': {'electricity production, at power plant/hard coal, pre, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/lignite, pre, pipeline 200km, storage 1000m'},
#  'Coal CHP': {'heat and power co-generation, hard coal',
#   'heat and power co-generation, lignite'},
#  'Coal CHP CCS': {'electricity production, at co-generation power plant/hard coal, oxy, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/hard coal, oxy, pipeline 400km, storage 3000m',
#   'electricity production, at co-generation power plant/hard coal, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/hard coal, post, pipeline 400km, storage 1000m',
#   'electricity production, at co-generation power plant/hard coal, post, pipeline 400km, storage 3000m'},
#  'Gas OC': {'electricity production, natural gas, conventional power plant'},
#  'Gas CC': {'electricity production, natural gas, combined cycle power plant'},
#  'Gas CHP': {'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical',
#   'heat and power co-generation, natural gas, conventional power plant, 100MW electrical'},
#  'Gas CHP CCS': {'electricity production, at co-generation power plant/natural gas, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/natural gas, pre, pipeline 200km, storage 1000m'},
#  'Gas CC CCS': {'electricity production, at power plant/natural gas, post, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/natural gas, post, pipeline 400km, storage 1000m',
#   'electricity production, at power plant/natural gas, post, pipeline 400km, storage 3000m',
#   'electricity production, at power plant/natural gas, pre, pipeline 200km, storage 1000m',
#   'electricity production, at power plant/natural gas, pre, pipeline 400km, storage 3000m'},
#  'Geothermal': {'electricity production, deep geothermal'},
#  'Hydro': {'electricity production, hydro, reservoir, alpine region',
#   'electricity production, hydro, reservoir, alpine region, renewable energy products',
#   'electricity production, hydro, reservoir, non-alpine region',
#   'electricity production, hydro, reservoir, tropical region',
#   'electricity production, hydro, run-of-river',
#   'electricity production, hydro, run-of-river, renewable energy products'},
#  'Nuclear': {'electricity production, nuclear, boiling water reactor',
#   'electricity production, nuclear, pressure water reactor',
#   'electricity production, nuclear, pressure water reactor, heavy water moderated'},
#  'Nuclear_EPR': {'electricity production, Evolutionary Power Reactor (EPR)'},
#  'Nuclear_SMR': {'electricity production, Small Modular Reactor (SMR)'},
#  'Oil ST': {'electricity production, oil'},
#  'Oil CC': {'electricity production, oil'},
#  'Oil CC CCS': {'electricity production, at co-generation power plant/oil, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/oil, pre, pipeline 200km, storage 1000m'},
#  'Oil CHP': {'heat and power co-generation, oil'},
#  'Oil CHP CCS': {'electricity production, at co-generation power plant/oil, post, pipeline 200km, storage 1000m',
#   'electricity production, at co-generation power plant/oil, pre, pipeline 200km, storage 1000m'},
#  'Solar CSP': {'electricity production, solar thermal parabolic trough, 50 MW',
#   'electricity production, solar tower power plant, 20 MW'},
#  'Solar PV Centralized': {'electricity production, photovoltaic, commercial'},
#  'Solar PV Residential': {'electricity production, photovoltaic, residential'},
#  'Wind Onshore': {'electricity production, wind, 1-3MW turbine, onshore',
#   'electricity production, wind, 1-3MW turbine, onshore, renewable energy products',
#   'electricity production, wind, <1MW turbine, onshore',
#   'electricity production, wind, <1MW turbine, onshore, renewable energy products',
#   'electricity production, wind, >3MW turbine, onshore',
#   'electricity production, wind, >3MW turbine, onshore, renewable energy products'},
#  'Wind Offshore': {'electricity production, wind, 1-3MW turbine, offshore'},
#  'Wave': {'electricity production, wave energy converter'}}

# %%
inv.generate_daccs_map()
# Out:
# {'dac_solvent': {'carbon dioxide, captured from atmosphere, with a solvent-based direct air capture system, 1MtCO2'},
#  'dac_sorbent': {'carbon dioxide, captured from atmosphere, with a sorbent-based direct air capture system, 100ktCO2'},
#  'daccs_solvent': {'carbon dioxide, captured from atmosphere and stored, with a solvent-based direct air capture system, 1MtCO2'},
#  'daccs_sorbent': {'carbon dioxide, captured from atmosphere and stored, with a sorbent-based direct air capture system, 100ktCO2'}}

# %%
ndb.write_db_to_brightway("test_metals")
# Out:
# Write new database(s) to Brightway2.
# Prepare database 1.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:31
# Title: Writing activities to SQLite3 database:
#   Started: 06/19/2023 12:11:07
#   Finished: 06/19/2023 12:11:38
#   Total time elapsed: 00:00:31
#   CPU %: 86.50
#   Memory %: 11.62
# Created database: test_metals
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.

# %%
products = [
    'lightweighting, glider',
    'auxilliary battery inputs, for road vehicle',
    'battery cell, Li-ion, NMC622',
    'auxilliary electronics inputs, for fuel cell electric vehicle',
    'auxilliary material inputs, for fuel cell electric vehicle',
    'fuel cell stack, for fuel cell electric vehicle',
    'carbon fiber, weaved',
    'tank liner, polyethylene, high density',
    'transformer and rectifier unit, for electrolyser',
    'fuel tank, for diesel road vehicle',
    'fuel tank, for compressed hydrogen gas, 700bar',
    'fuel tank, for compressed hydrogen gas, 700bar',
    'fuel tank, for compressed hydrogen gas, 700bar',
    'fuel tank, for compressed natural gas, 200 bar',
    'charger, level 3, plugin, 200 kW, for electric vehicle',
    'gearbox, for lorry',
    'transmission, for lorry',
    'suspension, for lorry',
    'power electronics, for lorry',
    'auxilliary material inputs, for electric lorry',
    'retarder, for lorry',
    'cabin, for lorry',
    'frame, blanks and saddle, for lorry',
    'tires and wheels, for lorry',
    'auxilliary material inputs, for hydrid electric lorry',
    'exhaust system, for lorry',
    'internal combustion engine, for lorry',
    'lead acid battery, for lorry',
    'charger, level 3, with pantograph, 450 kW, for electric vehicle',
    'overhead lines, for electric vehicle',
    'battery cell, Li-ion, LTO',
    'charging station, 3kW',
    'battery cell,  Li-ion, LFP',
    'battery cell, Li-ion, NCA',
    'assembly operation, for lorry'
]

print(len(products))

acts = [a for a in bw.Database("brian") if a["reference product"] in products]

# %%
len(acts)

# %%
[a["reference product"] for a in acts]

# %%
import bw2data
bw2io.BW2Package.export_obj(obj=bw.Database("brian"), filename="db_for_brian.bw2package")

# %%
import bw2data
bw2io.BW2Package.import_file("db_for_brian.bw2package")

# %%
fp = "/Users/romain/Library/Application Support/Brightway3/ei39.f1469ad5eb0a071dc60323f6e0fce980/output/lci-brian.xlsx"
import bw2io

i = bw2io.ExcelImporter(fp)
i.apply_strategies()

# %%
ei_acts = list(set([(a["name"], a["reference product"]) for a in bw.Database("ecoinvent 3.9.1 cutoff")]))
print(len(ei_acts))

# %%
for ds in i.data:
    if (ds["name"], ds["reference product"]) in ei_acts:
        i.data.remove(ds)

# %%
for ds in i.data:
    if (ds["name"], ds["reference product"]) not in ei_acts:
        print(ds["name"])

# %%
len(i.data)

# %%
for ds in i.data:
    print(ds["name"])

# %%
i.match_database(fields=["name", "unit", "location"])
i.match_database("ecoinvent 3.9.1 cutoff", fields=["name", "reference product", "location", "unit"])
i.match_database("biosphere3", fields=["name", "categories", "unit"])

# %%
i.statistics()

# %%
list(i.unlinked)[-1]

# %%
bw.get_activity(('brian', '360c5e612a154ebb8cee2650bcc1bc75_copy1'))

# %%
for f in bw.Database("biosphere3"):
    if f["code"] == "e030108f-2125-4bcb-a73b-ad72130fcca3":
        print(f)

# %%
bw.projects.set_current("ei39")

# %%
l = []

for f in bw.Database("biosphere3"):
    l.append([f["name"], f["categories"][0], f["categories"][1] if len(f["categories"])>1 else "unspecified", f["unit"], f["code"]])

# %%
import csv

with open("flows_biosphere_39.csv", "w", newline="", ) as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerows(l)

# %%
ndb.scenarios[1]["iam data"].fuel_markets.sel(region="NEU").variables.values

# %%
import numpy as np
for ds in ndb.scenarios[1]["database"]:
    if ds["name"] == ("carbon dioxide, captured from atmosphere, with a solvent-based direct air capture system, 1MtCO2, with waste heat, and grid electricity",
                            "carbon dioxide, captured from atmosphere"):
            print(ds["name"], ds["location"])

# %%
for ds in ndb.scenarios[1]["database"]:
    if "carbon dioxide, captured" in ds["name"]:
        print(ds["name"], ds["location"])

# %%
ndb.scenarios[0]["iam data"].fuel_markets.sel(region="WEU", year=2050)

# %%
ndb.scenarios[0]["iam data"].fuel_markets.sel(region="WEU")

# %%
ndb.update_electricity()

# %%
ndb.scenarios[0]["iam data"].fuel_markets

# %%
ndb.generate_scenario_report()

# %%
ndb.generate_change_report()

# %%
ndb.update_all()

# %%
ndb.generate_scenario_report()

# %%
ndb.generate_change_report()

# %%
ndb.scenarios[0]["iam data"].gains_data_IAM

# %%
ndb.update_all()

# %%
ndb.write_db_to_brightway(["test_dac", "test_dac2"])

# %%
from premise.geomap import Geomap

# %%
Geomap()

# %%
Geomap(model="remind").geo.keys()

# %%
ndb.scenarios[0]["iam data"].carbon_capture_rate.sel(variables="steel")

# %%
for ds in ndb.scenarios[0]["database"]:
    for e in ds["exchanges"]:
        if e["name"].startswith("CO2 capture, at cement production plant"):
            print(e["name"], e.get("location"), e["amount"])
            print(ds["name"])
            print("--------------------")
